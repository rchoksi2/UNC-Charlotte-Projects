# %% [markdown]
# # Training Encoder Decoder Model

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import os

# %%
df = pd.read_csv('/content/drive/MyDrive/6156 Project/eng_jpn.txt',sep='\t',names=['Japanese','English'])

# %%
df.head()
# Out:
#   Japanese English
# 0      行け。     Go.
# 1   行きなさい。     Go.
# 2   こんにちは。     Hi.
# 3    もしもし。     Hi.
# 4    やっほー。     Hi.

# %%
df.Japanese = df.Japanese.apply(lambda x: 'sos '+ x +' eos')

# %%
jap_vocab= set()
for sent in df.Japanese:
    for word in sent.split():
        if word not in jap_vocab:
            jap_vocab.add(word)

# %%
eng_vocab= set()
for sent in df.English:
    for word in sent.split():
        if word not in eng_vocab:
            eng_vocab.add(word)

# %%
len(jap_vocab), len(eng_vocab),
# Out:
# (52194, 18524)

# %%
JAP_VOCAB_SIZE= len(jap_vocab)+1
ENG_VOCAB_SIZE= len(eng_vocab)+1
print(JAP_VOCAB_SIZE)
print(ENG_VOCAB_SIZE)
# Out:
# 52195
# 18525

# %%
jap_words = sorted(list(jap_vocab))
eng_words = sorted(list(eng_vocab))

# %%
# create japanese and english dictionaries
jap_word_index = dict((w, i) for i, w in enumerate(jap_words))
eng_word_index = dict((w, i) for i, w in enumerate(eng_words))

# %%
jap_word_index
# Out:
# {'"password"': 0,
#  '100ドルまで使っていいですよ。': 1,
#  '10時の約束なのに、未だに何の連絡もないのはおかしいな。どこかで事故にでも遭ったんじゃないだろうか。': 2,
#  '10時まで仕事するつもりなの？': 3,
#  '10月20日の昼の２時半はどうかしら？': 4,
#  '10月20日午後２時３０分はどう？': 5,
#  '10月からトムを見かけてないよ。': 6,
#  '10月にまた会おう。': 7,
#  '10月にトムと会った。': 8,
#  '10月に僕はここにいなかった。': 9,
#  '10月に君らにまた会うのを待ちきれない。': 10,
#  '10月の最初の週に、ボストンに行くよ。': 11,
#  '10月はボストンにいた。': 12,
#  '10月以来、トムとは会ってないよ。': 13,
#  '12時45分とかどう？': 14,
#  '12時から1時まで、1時間の昼休みがある。': 15,
#  '12時間寝たのにまだ眠い。': 16,
#  '12月24日はクリスマスイブです。': 17,
#  '12歳です。': 18,
#  '16歳以下の子供を車に乗せて喫煙することは法律違反です。': 19,
#  '1853年、ペリーはついに東京湾へ入港した。': 20,
#  '1912年、タイタニック号は処女航海中に沈没した。': 21,
#  '1941年に戦争が始まった。': 22,
#  '1959年9月26日に、日本観測史上最大の台風が名古屋を襲った。': 23,
#  '1962年にアルジェリアはフランスから独立した。': 24,
#  '19時までに投函すれば、明日には届きますよ。': 25,
#  '1つ分からないことがあります。': 26,
#  '1人でいるの？': 27,
#  '1分は60秒です。': 28,
#  '1年間の留学でトムのフランス語力は飛躍的に向上した。': 29,
#  '1日5語ずつ英単語を覚えれば、1年で1825語、100年で182620語覚えることができます。': 30,
#  '1日か2日かかります。': 31,
#  '1日や2日で東京を見て回るなんて出来ない。': 32,
#  '1時間で終わらせます。': 33,
#  '1時間は60分です。': 34,
#  '1時間ほどお待ちいただけますか？': 35,
#  '1月に試験を受ける予定です。': 36,
#  '1番目が一番良いというわけじゃなかった。': 37,
#  '1週間は、7日です。': 38,
#  '1週間以内にお届けします。': 39,
#  '2003年、私は13歳だった。': 40,
#  '2013年10月20日にここで何があったか覚えてますか？': 41,
#  '2015年９月の日本の失業率は3.4パーセントだった。': 42,
#  '25ページの地図をご覧ください。': 43,
#  '25ページの地図を見てください。': 44,
#  '2つ目の信号を左に曲がってください。': 45,
#  '2回も約束破られて、まだあいつのこと信用してんの？': 46,
#  '2時30分に帰ってきます。': 47,
#  '2時半くらいに電話していい？': 48,
#  '2時半です。': 49,
#  '2時半に会いましょう。': 50,
#  '2時半に会おう。': 51,
#  '2時半に来て下さい。': 52,
#  '2時半に正門の前に迎えに来てください。': 53,
#  '2時半に正門前で会おう。': 54,
#  '2時半に着いた。': 55,
#  '2時半に閉まる。': 56,
#  '2時半までに来て下さい。': 57,
#  '2時半頃出た。': 58,
#  '2時半頃出発した。': 59,
#  '300ドルほど貸していただけませんか。': 60,
#  '30ドル借りてもいい？': 61,
#  '30ドル貸してもらえないかな？': 62,
#  '30ドル貸してもらえない？': 63,
#  '34ページの下から7行目を見てください。': 64,
#  '3人の生徒が簡単に挨拶をして、自分自身や自分の国のことを紹介した。': 65,
#  '3台の車を持っているんだよね？': 66,
#  '3年間交際していた彼氏と先日別れました。': 67,
#  '3歳になったばかりの息子がいます。': 68,
#  '50歳になっても、まだ彼女は息を呑むほど美しい。': 69,
#  '57便の荷物はどこにありますか。': 70,
#  '5分もかからなかったよ。': 71,
#  '5年後に戦争が始まった。': 72,
#  '5歳の時に自転車に乗れてた？': 73,
#  '6時半にお電話ください。': 74,
#  '6時半に会いましょう。': 75,
#  '6時半に会おう。': 76,
#  '6時半に電話してください。': 77,
#  '7時に帰るよ。': 78,
#  '7時半に朝食をとった。': 79,
#  '80円切手を1枚下さい。': 80,
#  '839号室なんですけど。': 81,
#  'Beispiel': 82,
#  'CIAについて何を知っていますか。': 83,
#  'DNA鑑定によって彼の無罪が証明された。': 84,
#  'FBIのものですが。': 85,
#  'Facebookやってる？': 86,
#  'Gif画像ファイル形式しか読み込めません。': 87,
#  'IKEAの家具好き？': 88,
#  'JAL124便の搭乗口はどこですか。': 89,
#  'Jackson』です。': 90,
#  'Nations': 91,
#  'PDFって何の略か知ってる？': 92,
#  'PKOが何の略語だか知ってる？': 93,
#  'SSH': 94,
#  'Tatoebaとは日本語で「例えば」という意味です。': 95,
#  'Tシャツが後ろ前だよ。': 96,
#  'Tシャツとジーンズはこの場にふさわしくない。': 97,
#  'Tシャツを買いました。': 98,
#  'Tシャツを買ったの。': 99,
#  'Tシャツ裏返しだよ。': 100,
#  'Tシャツ買ったんだ。': 101,
#  'UFO見たことある？': 102,
#  'UN': 103,
#  'United': 104,
#  'Wi-Fi': 105,
#  'Wi-Fiのパスワードを教えていただけますか？': 106,
#  'YouTubeでそれ見たよ。': 107,
#  'a': 108,
#  'eos': 109,
#  'iPadを買いたいなんて一度も思った事がなかった。': 110,
#  'iPadアプリを作るのがこんなに大変だとは思ってもみなかった。': 111,
#  'iPhoneを見せびらかすのはやめてよ。': 112,
#  'info@example.com': 113,
#  'its': 114,
#  'o': 115,
#  's': 116,
#  'sos': 117,
#  'subway': 118,
#  'underground': 119,
#  'you」は日本語で何て言うの？': 120,
#  '。': 121,
#  '〆切に間に合いますか。': 122,
#  '「thank': 123,
#  '「あ、ごめんなさい。こんなに場所をとっていたなんて気付きませんでした。」': 124,
#  '「あ、トム赤くなってる！」「なってねえし！」': 125,
#  '「ああ」は感嘆詞だ。': 126,
#  '「あなたが仕事を辞めたって聞いたんだけど」「本当はクビになったんだよ」': 127,
#  '「あなたの家はどこですか」「それは向こうです」': 128,
#  '「あなたの本はどこですか」「机の上です」': 129,
#  '「あなたの辞書を使ってもいいですか」「はい、どうぞ」': 130,
#  '「あなたはいつテレビを見ますか」「夕食後です」': 131,
#  '「あなたはいつ泳ぎますか」「７月です」': 132,
#  '「あなたはいつ起きますか」「８時です」': 133,
#  '「あなたはかなり英語が得意なんですよね？」「そう思いたいものです。」': 134,
#  '「あなたはどこに住んでるのですか」「東京です」': 135,
#  '「あなたは何が欲しいですか」「犬が欲しいです」': 136,
#  '「あなたは先生ですか」「その通りです」': 137,
#  '「あなたは先週テレビを見ましたか」「いいえ」': 138,
#  '「あなたは教師ですか」「はい、そうです」': 139,
#  '「あなた達は学生ですか」「はい、そうです」': 140,
#  '「あの人たちは、またストをやるんだろうか」「どうもそうらしいね」': 141,
#  '「あの方とあなたのご関係はどうなのですか」「私は彼の父です」': 142,
#  '「あの本がほしい」と彼は心の中で思いました。': 143,
#  '「あの狭い部屋に３０ドルはあんまりだ」と彼は思いました。': 144,
#  '「あの赤い服を着るのはよしなさい」「なぜいけないの」': 145,
#  '「あばたもえくぼ」って言うからね。': 146,
#  '「ありがとう。もう一つケーキをいただきます」と内気な青年は言った。': 147,
#  '「ありがとう」「とんでもない。私の方こそ、ありがとう」': 148,
#  '「ありがとう」「どういたしまして」': 149,
#  '「ありがとう」ぐらい言ってもよさそうなのに。': 150,
#  '「ありがとう」はフランス語でなんて言うの？': 151,
#  '「ありがとうございました」「どういたしまして」': 152,
#  '「ありがとうございます」「どういたしまして」': 153,
#  '「あれらはあなたの本ですか」「いいえ、違います」': 154,
#  '「いいえ、いました」とその学生は答えた。': 155,
#  '「いいよ」とは言えないな。': 156,
#  '「いっしょにきませんか」「ええ、喜んで」': 157,
#  '「いつそれを買ったの」「ええと、先週でした」': 158,
#  '「いつ戻ったの？」「一昨日だよ」': 159,
#  '「いつ戻りますか」「天候次第です」': 160,
#  '「いつ起きるの？」「朝八時だよ」': 161,
#  '「いま何時？」「3時20分」': 162,
#  '「おいしい？」「うん、おいしい」': 163,
#  '「おはようございます。今日は遅かったですね」「うん。ちょっと手間取っちゃって」': 164,
#  '「おばあちゃんは？」「ソファで寝てるよ」': 165,
#  '「お住まいはどちらですか？」「東京です」': 166,
#  '「お宅にお邪魔してもよろしいですか。」「いつでも構いませんよ。」': 167,
#  '「お腹減ってきた」「僕も」「ご飯にする？」「うん」': 168,
#  '「お腹空いた？」「いつも空いてるよ」': 169,
#  '「お腹空いてる？」「ううん、あんまり」': 170,
#  '「お茶でも入れようか？」「うん、お願い」': 171,
#  '「お願い」って言えよ。': 172,
#  '「お飲み物はいかがですか？」「一つもう頂きました」': 173,
#  '「かぼちゃは何個欲しいの？」「３個、お願いします」': 174,
#  '「ここから学校までどのくらいかかりますか」「歩いて約１０分です」': 175,
#  '「ここから駅までどのくらい距離がありますか」「約２マイルです」': 176,
#  '「ここでたばこを吸ってもいいですか」「はい、いいですよ。」': 177,
#  '「ここに駐車してもよろしいですか」「いいえ、いけません」': 178,
#  '「ここ来たことある？」「いや、初めて来た」': 179,
#  '「こちら温めますか？」「いえ、結構です」': 180,
#  '「このキノコ食べられる？」「何だって食べられるさ、一度ならね」': 181,
#  '「このハンカチはいくらですか」「９５セントです」': 182,
#  '「このペンを借りてもいいですか」「ええ、どうぞ」': 183,
#  '「この作戦はうまくいくだろうか」彼はひとりごちた。': 184,
#  '「この鉛筆お借りしていいですか？」「ええ、どうぞ」': 185,
#  '「この鉛筆を使ってもいいですか」「はい、いいです」': 186,
#  '「この電話をお借りしてもいいですか」「ええ、どうぞ」': 187,
#  '「これいくらで買ったの？」「20ユーロくらい」「安っ！': 188,
#  '「これが理解できないんです。」「私もです。」': 189,
#  '「これは何？」「桃だよ」': 190,
#  '「これは誰のイスですか」「私のものです」': 191,
#  '「これらは何ですか」「あなたの写真です」': 192,
#  '「これ以上何も言うことはありません、いいわけをするのはいやですから」と彼は言った。': 193,
#  '「ごきげんいかがですか」「おかげさまで元気です」': 194,
#  '「さあ行きましょう」と彼は私に言った。': 195,
#  '「すぐ帰ってくるから」と彼は付け足した。': 196,
#  '「すごくあなたが気になるの」と彼女は告白した。': 197,
#  "「そこアポストロフィが抜けてる。it's": 198,
#  '「そのうちに、あなたのところにお邪魔してもいいですか」「どうぞ、どうぞ」': 199,
#  '「それって、本当のこと？」「そうだと思う」': 200,
#  '「それはいい考えだ」と、私は心の中で思った。': 201,
#  '「それはいくらかかりましたか」「千円かかりました」': 202,
#  '「それ本当？」「そう思うよ」': 203,
#  '「ちょっと目つぶってて」とトムが囁いた。メアリーが目をつぶると、トムはメアリーの唇にそっとキスをした。': 204,
#  '「どういたしまして。」': 205,
#  '「どうしたの？」「スピーカーの調子が悪いんだ」': 206,
#  '「どうしたらいいだろう？」と私は独り言を言った。': 207,
#  '「どうしたんだ」「車が故障したんだ」': 208,
#  '「どうした？」「鍵がない」': 209,
#  '「どうして来なかったんだ」「仕方がなかったんだよ」': 210,
#  '「どうして行かないの？」「行きたくないからだよ。」': 211,
#  '「どうして靴下っていつも片一方だけなくなるんだろう？」「両方なくなったらなくなったことに気づかないんだよ」「あ、そっか」': 212,
#  '「どうすりゃいいんだ？」僕は独り言ちた。': 213,
#  '「どうぞ座って下さい」と彼は言った。': 214,
#  '「どこにいるの？」「ここだよ」': 215,
#  '「どこに座ればいいですか？」「どこでもいいですよ」': 216,
#  '「どこへ行ってきたのですか」「床屋へ行ってきたところです」': 217,
#  '「どこへ行ってきましたか」「友人を見送りに駅へ行ってきました」': 218,
#  '「どこ行ってたの？」「友だちを見送りに駅へ行ったんだ」': 219,
#  '「どちらに滞在していますか」「あのホテルに滞在しています」': 220,
#  '「どなたか手伝って戴けませんか？」「はい。私でよろしければ。」': 221,
#  '「どなたですか」「お母さんよ」': 222,
#  '「どなたですか」「私です」': 223,
#  '「どなたですか？」「俺だよ」': 224,
#  '「どのようにしてその公園に行きましたか」「バスで行きました」': 225,
#  '「どのように登校しているのですか」「バスです」': 226,
#  '「なぜ行かないの」「行きたくないからさ」': 227,
#  '「なんで怒ってるの？」': 228,
#  '「なんで私がトムのこと好きって分かったの？」「そんなの見てれば分かるよ」': 229,
#  '「ねえ、なんでそんなにかっこいいの？」「生まれつきだよ」': 230,
#  '「ねえねえ、トムとメアリーって付き合ってるの？」「いや、あの二人はただ仲いいだけだよ」': 231,
#  '「ねえメアリー」「なに？」「メアリーって彼氏いるの？」「なんで？」': 232,
#  '「ひかり」は時速２００キロで走る。': 233,
#  '「ほかに何か要りますか」「それだけで結構です」': 234,
#  '「ぼくは、買いたいものがあるのだ」と男の子がいいました。': 235,
#  '「ぼく日本人」少年は答えた。': 236,
#  '「まぁまぁだね。」': 237,
#  '「まさかトムが勝つとは思わなかったなあ」「僕もだよ」': 238,
#  '「またトムから電話？」「うん。このところ毎晩かかってくるの。番号教えるんじゃなかった」': 239,
#  '「もう一本くれ」と彼が言った。': 240,
#  '「もう一杯コーヒーを飲みませんか」「いいえけっこうです」': 241,
#  '「もし疲れているなら寝たらどう？」「僕が今寝たらあまりに早く目覚めてしまうから」': 242,
#  '「もっとコーヒーはいかがですか」「もう結構です？十分頂きました」': 243,
#  '「もっと召し上がりますか」「いいえ、じゅうぶんいただきました」': 244,
#  '「よくなるにはこの薬全部飲まないとね」看護師は言った。': 245,
#  '「わたしは、ぶら下がるには、年をとりすぎています。」と男の子はいいました。': 246,
#  '「アルコール類はただですか」「ご婦人方に限ります」': 247,
#  '「アー」といってください。': 248,
#  '「イスの上に本がありますか」「はい、あります」': 249,
#  '「ウィーンまでは歩いてどのくらいかかりますか」、と彼はたずねた。': 250,
#  '「オーストラリアからですか」とフィリピン人はたずねました。': 251,
#  '「オーストラリアは初めてですか？」「はい、初めて来ました」': 252,
#  '「カボチャ、いくつ欲しいの？」「３つ、お願いします」': 253,
#  '「ガリバー旅行記」を読んだことがありますか。': 254,
#  '「キャッチボールしようか」「よし、是非やろう」': 255,
#  '「ギターがひけますか」「はい、ひけます」': 256,
#  '「ケーキはお好きですか」「はい、好きです」': 257,
#  '「ゲティスバーグ演説」は簡潔なスピーチです。': 258,
#  '「コーヒーでもどうだい」「できればそうしたいのだが、いくところがあるのでね」': 259,
#  '「コーヒーを持ってきてあげるよ。」「どうもありがとう。」': 260,
#  '「コーヒー飲む？」「インスタント？」「そうだよ」「なら、いらない」': 261,
#  '「ジュテーム」はフランス語で「愛してる」という意味です。': 262,
#  '「スポーツは好きですか」「はい特に野球が好きです」': 263,
#  '「スーパーソニック」は世界制覇すると思うかい。': 264,
#  '「スーパーマン」は今月その映画館で上映中です。': 265,
#  '「テストどうだった？」「思ってたほど難しくなかった」': 266,
#  '「テレビの音を小さくしてもらえませんか」って言ったんですよ！': 267,
#  '「トイレの便座からエイズが感染することってあるの？」「いいえ、ありません」': 268,
#  '「トイレ行きたいな」「僕も行きたい」「駅で行っとけばよかったね」': 269,
#  '「トム、ご飯冷めちゃうよ？」「ちょっと待って、今行く！」': 270,
#  '「トムがどれだけお金を稼いでいるか知ってる？」「私が知るわけないでしょう。」': 271,
#  '「トムちょっと痩せた？」「僕も思った。昔もっとぽっちゃりしてたよね」': 272,
#  '「トムって知ってるでしょ?」「『知ってる』とは言えないな。」': 273,
#  '「トムとはまだ続いてるの？」「いや、先月初めに別れた」': 274,
#  '「トムとは前から知り合いだったの？」「いやいや、さっき知り合ったばっかりだよ」': 275,
#  '「トムとメアリーが離婚するって聞いたよ。」「それは噂だよ。」': 276,
#  '「トムのこと嫌いなの？」「嫌いじゃないけど、ああいう人ちょっと苦手なんだよね」': 277,
#  '「トムのこと嫌いなの？」「嫌いじゃないよ。ちょっと変わった人だなとは思うけど」': 278,
#  '「トムのパーティー行く？」「まだ分かんない」': 279,
#  '「トムの卒業のお祝いに、車を買ってあげようよ」「それはすごくいい考えだね」': 280,
#  '「トムはどこ？」「僕が知るわけないじゃん」': 281,
#  '「トムはもうすぐここに来ます」「どれくらいすぐですか」': 282,
#  '「トムは今日学校あるの？」「いや、台風で休校になった」': 283,
#  '「トムは腕立て何回できる？」「前は100回くらい余裕だったけど今はどうだろ。50回くらいかな」': 284,
#  '「トランプしたいなあ。」「私も。」': 285,
#  '「トランプしたいなあ」「私も」': 286,
#  '「トランプやりたい」「俺も俺も！」': 287,
#  '「ドアを閉めて下さいませんか」「ええ、いいですよ」': 288,
#  '「ニューヨークへ行ったことがありますか」「ええ２、３度行ったことがあります」': 289,
#  '「ノー」と言うのは、トムにとっては難しいことだった。': 290,
#  '「バイオテクノロジー」という言葉が普通に使われるようになったのは、いつ頃ですか。': 291,
#  '「バスはあとどのくらいで来ますか」「５分で来ます」': 292,
#  '「ペンを持っていますか」「はい、持っています」': 293,
#  '「ユリ」を英語で何といいますか。': 294,
#  '「ロミオとジュリエット」が劇場で上演されている。': 295,
#  '「一緒にいいかい」「もちろんいいとも」': 296,
#  '「一緒に行ってもいいですか」「どうぞ」': 297,
#  '「三角形」を定義するのは難しいです。': 298,
#  '「乗車券を拝見できますか」「はい、どうぞ」': 299,
#  '「事実」と「意見」を峻別するということは重要なことだと思います。': 300,
#  '「今何時ですか。」「３時２０分です。」': 301,
#  '「今何時ですか」「１０時です」': 302,
#  '「今出かけてはいけない」「どうしてだめなの」': 303,
#  '「今夜電話してもいい？」「いいよ」': 304,
#  '「今日のこと、トムには話さない方がいいんじゃないかな」「私もそう思う」': 305,
#  '「今日の新聞にいいニュース何かある？」「いや、特にないね」': 306,
#  '「今日はこれまで」と先生が言った。': 307,
#  '「今日ほんと暑いね」「うん、暑いね」': 308,
#  '「今日何曜日ですか？」「水曜日です」': 309,
#  '「今朝は調子はいかがですか」「かなりいいですよ、ありがとう」': 310,
#  '「会合はどのくらい続きそうですか」「２時間です」': 311,
#  '「会社」を英語で何といいますか。': 312,
#  '「会社」を表す英語は何ですか。': 313,
#  '「伝言を承りましょうか」「いえ、結構です」': 314,
#  '「何かお探しですか？」「いえ、見てるだけです」': 315,
#  '「何かご用は？」「ドレスを探しています」': 316,
#  '「何かする事があるの」「いや別に」': 317,
#  '「何かやることがあるの？」「特にない」': 318,
#  '「何か書くものをくれ」「このボールペンでいいですか」': 319,
#  '「何か書くものをくれ」「これでいいですか」「うん、それでいい」': 320,
#  '「何て言いましたか。」「何も言ってませんよ。」': 321,
#  '「何の勉強してるの？」「フランス語よ」': 322,
#  '「何をさしあげましょうか」「いや、けっこう。ただ見て回っているだけだから」': 323,
#  '「何を差し上げましょう？」「いや、結構です。ただ見ているだけです」': 324,
#  '「何を隠そうとしてるんだよ。」「何も。」': 325,
#  '「何処に行っていたの？」「歯医者に行っていたのだ」': 326,
#  '「何勉強してるの？」「フランス語」': 327,
#  '「何故だか、分かりません。」': 328,
#  '「何故？」—': 329,
#  '「何時だろうか」と彼は思った。': 330,
#  '「何時ですか」「１０時半です」': 331,
#  '「何時帰ってきたのですか」「一昨日です」': 332,
#  '「信用して」と彼は言った。': 333,
#  '「僕の父は酒を飲みません」「私の父もなんです」': 334,
#  '「僕は水泳が下手です」「私もそうなのです」': 335,
#  '「兄弟はいますか？」「いいえ、一人っ子です」': 336,
#  '「入ってよろしいですか」「はい、どうぞ」': 337,
#  '「出て行け」と言ったはずだ。': 338,
#  '「動くな、全員！」と銀行強盗は叫んだ。': 339,
#  '「南瓜は、何玉欲しい？」「３玉、お願いします」': 340,
#  '「友情」という題で作文を書きなさい。': 341,
#  '「君がそれをするのをやめさせなければいけないな。」「何をするのをやめさせるって？」': 342,
#  '「君の鉛筆を使ってもよいですか」「ええ、どうぞ」': 343,
#  '「君は彼女の住所を知っているかい」と私は彼にたずねた。': 344,
#  '「哺乳瓶」なんて言葉、久々に聞いたよ。': 345,
#  '「国連」は「国際連合」の略です。': 346,
#  '「塩を取っていただけませんか」「はい、どうぞ」': 347,
#  '「塩を取って下さい。」「はい、どうぞ。」': 348,
#  '「塩を取って下さい」「はい、どうぞ」': 349,
#  '「夕食後勉強するつもりですか」「はい」': 350,
#  '「大変な一日でしたからお疲れでしょうね」「いいえ、一向に」': 351,
#  '「嫌だ」と言いたいのに、時々「いいよ」と言ってしまう。': 352,
#  '「学校はどうやって通ってるの？」「バスです」': 353,
#  '「学校はどうやって通ってるの？」「バス通です」': 354,
#  '「学校まではどれくらいありますか？」「歩いて１０分ぐらいですね」': 355,
#  '「安いんだね。10ヤードもらおうかな。」と、その女の子は答えた。': 356,
#  '「少し詰めていただけませんか。」': 357,
#  '「居住外国人」とは、どういう意味ですか。': 358,
#  '「市長選挙をどう思いますか」「わかりません」': 359,
#  '「帰り次第、こちらからお電話させましょうか」「お願いします」': 360,
#  '「年はいくつ？」「16歳です。」': 361,
#  '「彼の本はどこですか」「それはテーブルの上です」': 362,
#  '「彼の病気は重いのかな」「そうでないといいね」': 363,
#  '「彼の話は本当かな」「本当ではないでしょう」': 364,
#  '「彼はいつ勉強しますか」「夕食前です」': 365,
#  '「彼はすぐよくなるでしょうか」「そうは思いません」': 366,
#  '「彼はすぐよくなるでしょうか」「そう思います」': 367,
#  '「彼はすぐ帰ってきますか」「すぐには帰らないと思います」': 368,
#  '「彼はもう来ないよ」タバコをすっていた男が言った。': 369,
#  '「彼は仕事のあとコーヒーを飲みたがっています」「私もです」': 370,
#  '「彼は明日泳ぎますか」「はい」': 371,
#  '「彼は昨日手紙を書きましたか」「はい」': 372,
#  '「彼は来ますか」「来ないと思います」': 373,
#  '「彼は来ると思いますか」「来ないといいね」': 374,
#  '「彼は正しいですか」「そうは思いません」': 375,
#  '「彼は試験に合格するでしょうか」「だめだと思います」': 376,
#  '「彼は音楽が好きですか」「はい、好きです」': 377,
#  '「彼らの計画については何も知りません」と彼は言った。': 378,
#  '「彼らはその法案を可決したの」「うん、とうとう通過させたんだ」': 379,
#  '「彼女はどういうつもりかしら」と思った。': 380,
#  '「彼女はテニスをしますか」「はい、します」': 381,
#  '「彼女は何才ですか」「１２才です」': 382,
#  '「彼女は時計を買いましたか」「ええ、買いました」': 383,
#  '「彼女は本を読んでいますか」「はい」': 384,
#  '「彼女は犬を飼っていますか」「いいえ」': 385,
#  '「彼女は若いですか」「はい」': 386,
#  '「彼女は音楽が好きだ」「私もそうだ」': 387,
#  '「彼女は音楽が好きではない」「私も好きではない」': 388,
#  '「怒ってないってば」': 389,
#  '「怒ると彼はトラになる」というのは隠喩の例である。': 390,
#  '「急ぐな」と彼は言いたした。': 391,
#  '「恋人にさよならのキスくらいしないと、キスしてあばよ、ということになるぞ」とトムは言ったが、それは「恋人に別れのキスくらいしないと、これが今生の別れになるぞ」という意味だった。': 392,
#  '「悪い風邪を引きました」「それはいけませんね」': 393,
#  '「愛してる」ってフランス語でなんていうの？': 394,
#  '「愛してるよ」「私もよ」': 395,
#  '「戻ったのはいつなの？」「おととい戻ったよ」': 396,
#  '「手伝ってくださいませんか」「喜んで」': 397,
#  '「手伝ってくれてありがとう。」': 398,
#  '「手伝ってくれてありがとう」「どういたしまして」': 399,
#  '「散歩しませんか」「いいですね、よろこんで」': 400,
#  '「散歩に行かない？」「もう少し日が陰ってからにしようよ」': 401,
#  '「散歩に行かない？」「もっと涼しくなってからにしようよ」': 402,
#  '「文化相対主義」とはどういう意味ですか。': 403,
#  '「新年おめでとう！」「あなたも！」': 404,
#  '「旅行が好きですか」「その通りです」': 405,
#  '「明日やるよ」「それ昨日も言ってた」': 406,
#  '「明日ピアノをひくつもりですか」「いいえ」': 407,
#  '「明日雨が降るだろうか」「降らないと思う」': 408,
#  '「映画に行きませんか」「ええ行きましょう」': 409,
#  '「昨日何時に寝た？」「4時」「えー、そんな遅くまで何してたの？」「元彼と電話してた」': 410,
#  '「昨日何時まで起きてたの？」「2時半ぐらい」': 411,
#  '「時々、彼との離婚を考えることがあるの。」「冗談言わないでよ！」': 412,
#  '「時々、彼と離婚しようと思うの」「冗談だろう！」': 413,
#  '「時間通りに、教室にうまく行き着くことができる」と彼は思った。': 414,
#  '「晴れてきそうですか」「そうなってほしいね」': 415,
#  '「机の中に本がありますか」「いいえ、ありません」': 416,
#  '「椎茸」はキノコの一種だ。': 417,
#  '「次はどうしょうか」と彼女は独り言を言った。': 418,
#  '「気分が悪かったけど、もう大丈夫だよ」と、彼は言った。': 419,
#  '「気分はどうですか。」と彼は尋ねた。': 420,
#  '「気分はどうですか」と彼は尋ねた。': 421,
#  '「水を少しください」「いいですよ」': 422,
#  '「泣きっ面に蜂」だな。': 423,
#  '「洞穴の中で何が起こっているんだろう？すごく知りたいなあ」「見当もつかないよ」': 424,
#  '「火事だ！」とトムは叫んだ。': 425,
#  '「疲れたか」「いいや、ちっとも」': 426,
#  '「痩せている」と言うよりも「細い」と言った方が失礼に当たりません。': 427,
#  '「白い帽子をかぶっている男の人は誰ですか」と私は彼女に言った。': 428,
#  '「砂糖を取ってくれませんか」「はい、どうぞ」': 429,
#  '「研究はどうですか」「まあまあです」': 430,
#  '「私が人気を得ているのは彼のおかげなの」と彼女は言った。': 431,
#  '「私が出ます。」': 432,
#  '「私のことまだ怒ってる？」「いや、全然」': 433,
#  '「私のどこが好きなの？」「全部」': 434,
#  '「私のノートはどこにありますか」「それはイスの上です」': 435,
#  '「私の事は放っておいてよ」と彼女は怒って言った。': 436,
#  '「私の仕事を手伝ってくれませんか」「いいですよ」': 437,
#  '「私の変わりにこれをしていただけませんか」「私は大変に忙しいものですから」': 438,
#  '「私の意見では」弟が言った。「あなたは間違っている」': 439,
#  '「私の父は建築家です。そして私も建築家になりたいと思います」と彼は言った。': 440,
#  '「私の英語の宿題を手伝ってくれませんか」「いいですとも」': 441,
#  '「私はその劇を見たことがあります」「私もあります」': 442,
#  '「私はとても幸運だわ」と彼女は心の中で思った。': 443,
#  '「私は幸福だわ」と彼女は心の中で思った。': 444,
#  '「私は彼に賛成です」「私もです」': 445,
#  '「私は日本人です」とその少年は答えた。': 446,
#  '「私は昼も夜も働くのにまだ慣れてない」「すぐに慣れるよ」': 447,
#  '「私は来週ハワイへ行くつもりよ」「ほんと？」': 448,
#  '「私もそう思うわ」と彼女は相づちを打った。': 449,
#  '「私ニンジンは嫌いよ」「私も嫌い」': 450,
#  '「窓を閉めましょうか」「お願いします」': 451,
#  '「窓を開けていただけませんか」「ええ、どうぞ」': 452,
#  '「窓を開けてくださいますか」「ええ、いいですよ」': 453,
#  '「窓を開けてくれませんか」「ええ、いいですとも」': 454,
#  '「納豆」の臭いはひどいが、食べるととてもおいしい。': 455,
#  '「結論」の目的は論文の主要な論点を要約することだ。': 456,
#  '「締め切りに間に合わなかったらどうなるかなあ」「きっと彼は怒るぞ！」': 457,
#  '「美味しい？」「うん、美味しいよ」': 458,
#  '「背高いの羨ましい」「そう？': 459,
#  '「腹減ったの？」「いつも減ってる」': 460,
#  '「芝生に入らないで下さい」という標識があった。': 461,
#  '「蝶々夫人」の舞台は長崎に置かれている。': 462,
#  '「被告人」という言葉は法律用語である。': 463,
#  '「誰か警察に電話したの？」「私がしました」': 464,
#  '「誰か車の中にいるのですか」「トムがいます」': 465,
#  '「誰がきみを手伝ったのですか」「トムです」': 466,
#  '「誰が一番早く来ると思う？」「トムじゃないのは確かだね」': 467,
#  '「誰に手伝ってもらったの？」「トムだよ」': 468,
#  '「調子はどうだ?」': 469,
#  '「論文できましたか」「いや、残念ですが、まだ書き終えていません」': 470,
#  '「買い物行くけどついて来る？」「行く！」': 471,
#  '「車にのせていただけませんか」「いいですとも」': 472,
#  '「車を借りていいかい」「いいとも、どうぞ」': 473,
#  '「転ばぬ先の杖」はことわざである。': 474,
#  '「辞書をお借りしていいですか」「どうぞどうぞ」': 475,
#  '「辞書をお借りしてもよろしいですか？」「もちろんです」': 476,
#  '「近頃どうも調子が悪くてね」「一度診てもらった方がいいよ」': 477,
#  '「速い」は「遅い」の反対。': 478,
#  '「道」という漢字の総画数は何画ですか。': 479,
#  '「長い１日だったのでお疲れでしょう」「いいえ、全然」': 480,
#  '「雨がすぐあがるでしょうか」「あがらないと思うよ」': 481,
#  '「雨が降るでしょうか」「降らないでしょう」': 482,
#  '「雨はすぐに上がるでしょうか｣「すぐには上がらないと思います」': 483,
#  '「雨はすぐやむかな」「やまないと思うよ」': 484,
#  '「雨やんだかな？」「やんでるといいね」': 485,
#  '「雨やんだ？」「いや、まだ降ってる」': 486,
#  '「雪、きれいだね」「そうだね。でもメアリーの方がもっときれいだよ」': 487,
#  '「電話が鳴っているよ。」': 488,
#  '「電話をお借りしてもいいですか」「どうぞどうぞ」': 489,
#  '「電話を使わせてもらってもいいですか」「ええ、どうぞ」': 490,
#  '「顔色がわるいけど具合が悪いのかい」「そういうわけでもないよ」': 491,
#  '「類義語」という意味の言葉は他にありますか？': 492,
#  '「飲み物は無料ですか」「ご婦人に限ってです」': 493,
#  '「黙って」と彼はささやいた。': 494,
#  '「５日前に彼女にあった」と彼は言った。': 495,
#  '「Ｔｈｅｒｅ': 496,
#  '『グレート・ギャツビー』は高校の頃に読みました。': 497,
#  'あ、いいこと思いついた。': 498,
#  'あ、ところでさ、君に見せたいものがあるんだ。': 499,
#  'あ、カメラ忘れた！': 500,
#  'あ、停電だ。': 501,
#  'あ、思い出した。トムから伝言があるんだよ。': 502,
#  'あ、雪だ！': 503,
#  'あぁ、お願いだから、その雑音を何とかして！': 504,
#  'ああ、お腹が空いた。': 505,
#  'ああ、ほっとした。': 506,
#  'ああ、ゆっくりやって下さい。急ぎませんから。': 507,
#  'ああいうことは二度としないように。': 508,
#  'ああいう話し方する人って、大っ嫌い。': 509,
#  'ああ恐い！': 510,
#  'ああ恥ずかしい！': 511,
#  'あいつ、自分が音痴だってこと知らないんだよ。': 512,
#  'あいつ。': 513,
#  'あいついい奴なんだ。': 514,
#  'あいつがどこに住むことになろうと俺たちの知ったことじゃない。': 515,
#  'あいつがガッツポーズするなんて、よっぽど嬉しかったんだろうな。': 516,
#  'あいつがトム？': 517,
#  'あいつが僕のことを「ばかなやつ」っていったんだよ。': 518,
#  'あいつってちょっと単純だよな。': 519,
#  'あいつとはどうも相性が合わないんだ。': 520,
#  'あいつには二度と会いたくない。': 521,
#  'あいつに因縁を付けられた。': 522,
#  'あいつに比べれば俺は幸せ者だ。': 523,
#  'あいつの冗談には飽き飽きした。': 524,
#  'あいつの名前、知ってるだろ？': 525,
#  'あいつの名前、知ってるんだろ？': 526,
#  'あいつの失礼な態度にはもう限界だよ。': 527,
#  'あいつの妹、とてもかわいいね。': 528,
#  'あいつの息の根を止めてやる。': 529,
#  'あいつの慇懃無礼なものの言い方、思い出すだけで不愉快になるよ。': 530,
#  'あいつの損を埋めてやらなくちゃならないんだ。': 531,
#  'あいつの生意気な話し方が嫌いだ。': 532,
#  'あいつの考えていることはさっぱりわからない。': 533,
#  'あいつの言うことなんか、あてにならないよ。': 534,
#  'あいつは、まったく頭にくるやつだ。': 535,
#  'あいつは、女の子がいるとかっこつけたがるんだから。': 536,
#  'あいつはちょっとシャイなんだ。': 537,
#  'あいつはクラスでいちばんのまぬけだ。': 538,
#  'あいつは何かと言うと知ったかぶりをする。': 539,
#  'あいつは何やかやにかこつけて、いつも文句ばかり言っている。': 540,
#  'あいつは優柔不断だから、彼女が愛想尽かしちゃったんだよ。': 541,
#  'あいつは嫌な奴だ。': 542,
#  'あいつは年中、親に金をせびってばかりいる。': 543,
#  'あいつは無鉄砲な男だ。': 544,
#  'あいつは苦手だ。': 545,
#  'あいつは誰にも好かれていない。だっていつもほらばかり吹いているから。': 546,
#  'あいつら、離婚するのかなあ。': 547,
#  'あいつらさ、折り返し電話してこなかったんだ。': 548,
#  'あいつらさ、電話かけ直してくれなかったんだよ。': 549,
#  'あいつらのケンカの理由なんて知らないよ。': 550,
#  'あいつらの友達なのか？': 551,
#  'あいつら嘘をついてたのか？': 552,
#  'あいつら嫉妬してんだよ。': 553,
#  'あいつら水の中に飛び込んだんだ。': 554,
#  'あいつら飲み過ぎだよ。': 555,
#  'あいつ僕をめがけて撃ったんだよ。': 556,
#  'あいつ絶対学校でいじめられてるよ。': 557,
#  'あいにく周囲に誰もいなかった。': 558,
#  'あいにく品切れになってしまったんですが。': 559,
#  'あいにく彼女は来なかった。': 560,
#  'あいにく明日は雨のようだね。': 561,
#  'あいにく母は留守です。': 562,
#  'あいにく雨が降った。': 563,
#  'あえてあの店には行かないようにしているんだ。': 564,
#  'あおいは、苦学生だから、そんな高級なもの、持てないです。': 565,
#  'あからさまに言えば彼は嫌いだ。': 566,
#  'あきらめるな。': 567,
#  'あくびをした。': 568,
#  'あくびをしないようにしなさい。': 569,
#  'あくびをしないようにしようとした。': 570,
#  'あけおめ！': 571,
#  'あげたお金で足りた？': 572,
#  'あごが痛い。': 573,
#  'あさきゆめみし': 574,
#  'あさって、時間がありませんか。': 575,
#  'あさってはトムの誕生日だ。': 576,
#  'あさって来てください。': 577,
#  'あしたの朝は寝過ごさないようにしなさい。': 578,
#  'あしたはよい天気だと思います。': 579,
#  'あしたは家に居るつもりだ。': 580,
#  'あすの朝出発しよう。': 581,
#  'あそこがトムの働いてるところだと思うんだ。': 582,
#  'あそこがトムの生まれた家です。': 583,
#  'あそこが彼の働いている会社です。': 584,
#  'あそこが私の父が働いているビルです。': 585,
#  'あそこで歌っている女の子は僕のお姉ちゃんだよ。': 586,
#  'あそこで歌っている少女は私の妹です。': 587,
#  'あそこなら花火が見やすいよ。': 588,
#  'あそこにいるあなたの友だち紹介してよ。': 589,
#  'あそこに座っている男は有名な歌手だ。': 590,
#  'あそこに彼の家が見えます。': 591,
#  'あそこに立っている人が店の主人です。': 592,
#  'あそこに行くつもりなの？': 593,
#  'あそこに進んでください。': 594,
#  'あそこに駐車するのは違法です。': 595,
#  'あそこに高いビルが見えますね。': 596,
#  'あそこのスーパー、何時までやってるか知ってる？': 597,
#  'あそこのテーブルをお願いしたいのですが。': 598,
#  'あそこの店はあまり好きじゃない。': 599,
#  'あそこの店は異常に高いよ。': 600,
#  'あそこの食べ物はうまいし値段も安いが、地の利が悪いのが難点だね。': 601,
#  'あたりには誰もいないようだ。': 602,
#  'あたりはもう暗い。': 603,
#  'あたりは水を打ったように静かだった。': 604,
#  'あたりは静かだ。': 605,
#  'あちこちに、美しい湖があります。': 606,
#  'あちゃー、こいつはばつが悪いわ。': 607,
#  'あちらに富士山が見えます。': 608,
#  'あちらに着いたら手紙をください。': 609,
#  'あちらの方は奥さんですか？': 610,
#  'あちらへつき次第お手紙を差し上げます。': 611,
#  'あっ、ごめんなさい。': 612,
#  'あっ、すみません。': 613,
#  'あっ、来た来た。': 614,
#  'あっ。すみません。それがルール違反になるとは知りませんでした。': 615,
#  'あっさり断られると思いきや、彼女は承諾してくれました。': 616,
#  'あったかいとこ行こう。': 617,
#  'あったかくしてなさい。': 618,
#  'あっちにエレベーターがあるみたいだよ。': 619,
#  'あっちに座って。': 620,
#  'あっちに行ってくれないかな。': 621,
#  'あっちへ行けって言ってるだろ！': 622,
#  'あっちへ行け！': 623,
#  'あてもなくあちこちを歩き回った。': 624,
#  'あと10分寝させて。': 625,
#  'あと1ヶ月遅く生まれてたら、人生大分違ってただろうなあ。': 626,
#  'あと1日しかない。': 627,
#  'あと1時間で出発です。': 628,
#  'あと30分もかかりません。': 629,
#  'あと3週間ボストンに滞在するという計画をすでにトムに話したよ。': 630,
#  'あと5分だけ一緒にいさせて。': 631,
#  'あとちょっとで自宅ってところで、ガス欠になったんだ。': 632,
#  'あとちょっとで魚が捕れたんだよ。': 633,
#  'あとでかけ直します。': 634,
#  'あとでチェックしよう。': 635,
#  'あとでホテルに電話を下さい。': 636,
#  'あとで後悔したりはしない。': 637,
#  'あとで懐かしく思ったりはしないだろう。': 638,
#  'あとで教えて下さい。': 639,
#  'あとで注文します。': 640,
#  'あとで添削せにゃ。': 641,
#  'あとで行くね。': 642,
#  'あとで電話するね。': 643,
#  'あとで電話ちょうだい。': 644,
#  'あとどれくらいかかると思う？': 645,
#  'あとは明日お話しします。': 646,
#  'あともう少し待って。': 647,
#  'あともう少し物事に前向きになることを学んだら、きっとトムももうちょっと人から好感をもたれるのだが。': 648,
#  'あと一息だ。': 649,
#  'あと何時間で到着しますか。': 650,
#  'あと１時間くらいしたら寝る。': 651,
#  'あと２日で、13歳になるよ。': 652,
#  'あと３分ってところでバスに間に合わなかったんだ。': 653,
#  'あと３０分ほどしたら戻ってくると思います。': 654,
#  'あなた、まだ独身でしょ。違う？': 655,
#  'あなた、やっちゃったじゃない。': 656,
#  'あなた、元妻って何人いるの？': 657,
#  'あなた、冷蔵庫のドア、開けっ放しになってたわよ。': 658,
#  'あなた、冷蔵庫開けっ放しだったわよ。': 659,
#  'あなた、分かってるかなぁ。': 660,
#  'あなた、困ったことになっているんでしょう？': 661,
#  'あなた、少食だね？': 662,
#  'あなた、恋愛したこと、ないんでしょ。': 663,
#  'あなた、正気なの？': 664,
#  'あなた、私のカップから飲んでますよ。': 665,
#  'あなた、随分偉ぶっているじゃないの。': 666,
#  'あなたかあるいは私が間違っている。': 667,
#  'あなたからさまざまなことを学びました。': 668,
#  'あなたからトムに言うのがベストだと思うよ。': 669,
#  'あなたから連絡がない限り、五時に会う予定でいます。': 670,
#  'あなたから５０ドルお借りしたいのですが。': 671,
#  'あなたがいたときの状況を説明してくれませんか。': 672,
#  'あなたがいないととても寂しいです。': 673,
#  'あなたがいないとどんなに寂しくなるか、私は全く気付かなかった。': 674,
#  'あなたがいない人生を思い描こうとしているのです。': 675,
#  'あなたがいなくてとても寂しい。': 676,
#  'あなたがいなくなるととても寂しくなります。': 677,
#  'あなたがおいでになることを公にするのは賢明ではないかもしれない。': 678,
#  'あなたがおかしいとは思わない。': 679,
#  'あなたがお出でになれない事を聞いてがっかりしました。': 680,
#  'あなたがここにいるということは、気に掛けているということだ。': 681,
#  'あなたがここに住んでいるのを知っています。': 682,
#  'あなたがご無事で嬉しいです。': 683,
#  'あなたがした事には、とやかく言いません。': 684,
#  'あなたがするのと同じ位に、相手が自分を愛してくれるかどうか判らないときには、誰かを愛することは難しい。': 685,
#  'あなたがそう考えるのは当然だ。': 686,
#  'あなたがそのことについて何も知らないのは変だ。': 687,
#  'あなたがそのパーティーに来れることを願っています。': 688,
#  'あなたがその仕事を終えるまで待ちます。': 689,
#  'あなたがそれについて何かするつもりだと思ってました。': 690,
#  'あなたがそれを理解してくれますように。': 691,
#  'あなたがそんなに気分が悪いなんて気づかなかった。': 692,
#  'あなたがそんな料理上手だとは知らなかったわ。': 693,
#  'あなたがただ手紙を書くだけで、あなたの父親は多くのことを心配しなくて済むだろう。': 694,
#  'あなたがたにお話をしてあげる。': 695,
#  'あなたがたのうちどちらが先にやってみますか。': 696,
#  'あなたがたのグループにはいりたいんですが。': 697,
#  'あなたがたの学校はどこにありますか。': 698,
#  'あなたがたは二人ともとても親切です。': 699,
#  'あなたがたは双子ですか？': 700,
#  'あなたがたは間違えることを怖がる必要はありません。': 701,
#  'あなたがちょっと驚くのではないかと思っていました。': 702,
#  'あなたがとても忙しいのは知ってます。': 703,
#  'あなたがどこに住んでいるのか知っています。': 704,
#  'あなたがどこへ行こうとも、わたしはついていきます。': 705,
#  'あなたがどこへ行こうとわたしはあなたについていく、と彼女は彼に言った。': 706,
#  'あなたがもう二度と私に会いたくないと思っているのは分かっています。': 707,
#  'あなたがやれば。': 708,
#  'あなたがコンサートに行かないなら、私も行きません。': 709,
#  'あなたがスポットを世話するって言ったとき、そういった責任が生じるのは分かっていたはずでしょ。': 710,
#  'あなたがタバコを吸っているのを見てびっくりしました。以前は吸っていなかったでしょう。': 711,
#  'あなたがトムと話しているのを見ました。': 712,
#  'あなたがボスだよ。': 713,
#  'あなたがメアリーの本を持ってあげてるのを見ました。': 714,
#  'あなたが一所懸命働くことが必要だ。': 715,
#  'あなたが今年の夏何をしたか知りたい。': 716,
#  'あなたが今日ここへ一番乗りだったよ。': 717,
#  'あなたが今言ったことで、私は古いことわざを思い出します。': 718,
#  'あなたが何をしたかは、あなたが何を言ったかより重要である。': 719,
#  'あなたが何を言おうと私は決心を変えるつもりはない。': 720,
#  'あなたが何を言ったとしても、私の気は変わらない。': 721,
#  'あなたが何歳か知っています。': 722,
#  'あなたが使った金額は全部でいくらですか。': 723,
#  'あなたが先生だということを知っています。': 724,
#  'あなたが助けてくれなかったら私はおぼれていたことでしょう。': 725,
#  'あなたが勝った。': 726,
#  'あなたが呼べば、彼は来るでしょう。': 727,
#  'あなたが困ったことになっているかもしれないと聞いたのですが。': 728,
#  'あなたが天才でないからといって、がっかりする必要はありません。': 729,
#  'あなたが失くしていたネックレスの一部を見つけました。': 730,
#  'あなたが女の子だからよ。': 731,
#  'あなたが好きなのを選びなさい。': 732,
#  'あなたが好きなカナダの歌手は誰ですか？': 733,
#  'あなたが好きな春の花はなに？': 734,
#  'あなたが家に帰って来た時、お母さんは何をしていましたか。': 735,
#  'あなたが密かに想いを寄せてる人が誰か知ってるよ。': 736,
#  'あなたが彼に計画について話さなければよかったのに。': 737,
#  'あなたが彼女を愛している理由を私に伝えてくれますか？': 738,
#  'あなたが必要なんです。': 739,
#  'あなたが忙しい事は分かっている。': 740,
#  'あなたが怖がっているのが分かります。': 741,
#  'あなたが恐れているものは何ですか？': 742,
#  'あなたが悪いと思います。': 743,
#  'あなたが成功すると確信している。': 744,
#  'あなたが戻って来てくれて嬉しいです。': 745,
#  'あなたが手を貸してくれることができるのではないかと思っていました。': 746,
#  'あなたが手伝ってくれなければ終わらせられないだろう。': 747,
#  'あなたが手伝ってくれるかもしれないと思いました。': 748,
#  'あなたが手伝ってくれれば私は本当に助かる。': 749,
#  'あなたが払うつもり？': 750,
#  'あなたが持ち主です。': 751,
#  'あなたが持っているのと同じカメラを買った。': 752,
#  'あなたが撮ったあの魚の写真を見ました。': 753,
#  'あなたが新聞を読み終えたら、私にも読ませてください。': 754,
#  'あなたが新車を運転しているのを見た。': 755,
#  'あなたが昨日私の事務所で会った人はベルギーの人です。': 756,
#  'あなたが時間内ににここに着くのは分かっていました。': 757,
#  'あなたが来られてうれしいわ。くつろいで下さい。': 758,
#  'あなたが来られるのでうれしい。': 759,
#  'あなたが来るかもしれないと思いました。': 760,
#  'あなたが来るのを楽しみにしています。': 761,
#  'あなたが来る前に私たちは行ってしまうよ。': 762,
#  'あなたが欲しいだけ取りなさい。': 763,
#  'あなたが正しいと思う。': 764,
#  'あなたが正しいのはわかっています。': 765,
#  'あなたが気に入った絵を描いた画家は私の友人です。': 766,
#  'あなたが決めて。': 767,
#  'あなたが流し台の修理をしてくれるのだと思っていました。': 768,
#  'あなたが猫を飼っていることは知らなかった。': 769,
#  'あなたが生まれたのは何年ですか？': 770,
#  'あなたが私たちの会社で働こうと思った理由を聞かせて下さい。': 771,
#  'あなたが私に会いたいとの伝言を受け取りました。': 772,
#  'あなたが私に何をしてほしいのかわからない。': 773,
#  'あなたが私を信用しないのなら、一緒に仕事をすることはできない。': 774,
#  'あなたが私を助けてくださるならば、その仕事を引き受けます。': 775,
#  'あなたが私を避けているのはわかっている。': 776,
#  'あなたが第一印象を示す機会は一度きりだ。': 777,
#  'あなたが行きたくないのなら行く必要はありません。': 778,
#  'あなたが行く前に言っておかなければならないことがあります。': 779,
#  'あなたが見つけたその傘はトムのですか？': 780,
#  'あなたが見ているこの花は薔薇です。': 781,
#  'あなたが詩を書くとは知らなかった。': 782,
#  'あなたが話したかった相手は誰？': 783,
#  'あなたが話す番です。': 784,
#  'あなたが話をしたいのは誰なの？': 785,
#  'あなたが話をしたがっていたのは誰ですか。': 786,
#  'あなたが誰かに劣等感を感じる理由はないのです。': 787,
#  'あなたが間違っているのは明らかです。': 788,
#  'あなたが電話をしてくれなかったのでがっかりした。': 789,
#  'あなたが駅に着くのにどのくらいかかりますか。': 790,
#  'あなたこの写真をどこで撮ってもらったのですか。': 791,
#  'あなたこれ、フランス語にどう訳すの？': 792,
#  'あなたたち、お互いに愛し合っているんでしょう？': 793,
#  'あなたたち、何をするつもりなの？': 794,
#  'あなたたち、元気にしてる？': 795,
#  'あなたたち、忙しい？': 796,
#  'あなたたちの話を立ち聞きするつもりはなかったんです。': 797,
#  'あなたたちはミュージシャンでしょ？': 798,
#  'あなたたちは何月生まれですか？': 799,
#  'あなたたちは指導者としてスペイン王を受け入れなければならない。': 800,
#  'あなたたち二人とも気は確かなの？': 801,
#  'あなたたち二人には共通点がたくさんあるだろうと思っていました。': 802,
#  'あなたたち全員ホームレスなの？': 803,
#  'あなたたち２人でケーキを分けなさい。': 804,
#  'あなただったら、この文、フランス語にどう訳す？': 805,
#  'あなたって、家族が大勢いるの？': 806,
#  'あなたって、本当にやるつもりなの？': 807,
#  'あなたって、本当に可愛いわね。': 808,
#  'あなたって、本当に幸せそうね。': 809,
#  'あなたって人懐っこいほう？': 810,
#  'あなたって本当に細かいわね。': 811,
#  'あなたって楽観的よね。': 812,
#  'あなたとあのレストランで食事ができたらよかったのに。': 813,
#  'あなたとご家族にお会いできることを楽しみにしています。': 814,
#  'あなたとは全く意見が合わない。': 815,
#  'あなたとキスしたい。': 816,
#  'あなたとトムがハグしてるの見ちゃった。': 817,
#  'あなたとトムってまだ付き合ってるの？': 818,
#  'あなたとトムのことが好きではありません。': 819,
#  'あなたとトムのことが嫌いではありません。': 820,
#  'あなたと一緒にいると、私は幸せだ。': 821,
#  'あなたと一緒にピクニックに行ったときのことを、今でも思い出せるよ。': 822,
#  'あなたと一緒に私がそこにいたらよかったのに。': 823,
#  'あなたと一緒に行きたいけど、行けない。': 824,
#  'あなたと一緒に過ごすのが好き。': 825,
#  'あなたと一緒に過ごす残りの人生を想像してみているのです。': 826,
#  'あなたと一緒に食事をするのは楽しい。': 827,
#  'あなたと二人だけで話そうとしても、いつも他の人と一緒にいるじゃないですか。': 828,
#  'あなたと出会えて、友達になれて、本当によかったと思っている。': 829,
#  'あなたと同い年の兄がいます。': 830,
#  'あなたと同じカメラを買った。': 831,
#  'あなたと同様に彼も大変親切だ。': 832,
#  'あなたと同様私も芸術家ではないのです。': 833,
#  'あなたと彼はとても親切ですね。': 834,
#  'あなたと御家族にお会いできることを楽しみにしております。': 835,
#  'あなたと文通することを楽しみにしています。': 836,
#  'あなたと私はソウルメイトなのよ。': 837,
#  'あなたと話したくありません。': 838,
#  'あなたなら、どうしますか？': 839,
#  'あなたならわかると思ってちょっと聞いてみたまでです。': 840,
#  'あなたなら良い先生になるでしょう。': 841,
#  'あなたなんかもう知らない。': 842,
#  'あなたにお任せします。': 843,
#  'あなたにお会いできてよかったです。お便りを楽しみにしています。': 844,
#  'あなたにお目にかかるのをとても楽しみにしています。': 845,
#  'あなたにお見せしたい新しい製品があります。': 846,
#  'あなたにお願い事をしてもよいでしょうか。': 847,
#  'あなたにここでひょっこり出会えてうれしい。': 848,
#  'あなたにこの問題が解けますか?': 849,
#  'あなたにこの本を英語に翻訳してもらいたい。': 850,
#  'あなたにすべて任せます。': 851,
#  'あなたにそれをして欲しくない。': 852,
#  'あなたにそんなにたくさんのお金は貸せないよ。': 853,
#  'あなたにとってひらめきの最大の源は何？': 854,
#  'あなたにとって頼りになるような友達を選びなさい。': 855,
#  'あなたには、それを証明することはできない。': 856,
#  'あなたにはこの人たちを批判する権利はない。': 857,
#  'あなたには姉妹がいますか。': 858,
#  'あなたには想像もつかない、でしょ？': 859,
#  'あなたには本当のことを言いたくないの。': 860,
#  'あなたには癌があります。': 861,
#  'あなたには真実を話したほうがいいですね。': 862,
#  'あなたにもう一度会いたいな。': 863,
#  'あなたにもう一度会うつもりはありません。': 864,
#  'あなたにキスしたい。': 865,
#  'あなたに不満があります。': 866,
#  'あなたに会いたいという人がいます。': 867,
#  'あなたに会いに来たのです。': 868,
#  'あなたに会えてうれしい。': 869,
#  'あなたに会えて大変うれしい。': 870,
#  'あなたに会えば彼は喜ぶと思います。': 871,
#  'あなたに僕の住所を教えない。': 872,
#  'あなたに力をお貸しすることは、ほとんど出来ないと思って下さい。': 873,
#  'あなたに嘘をついた。': 874,
#  'あなたに嘘をついていた。': 875,
#  'あなたに嘘をつくことはできなかった。': 876,
#  'あなたに嘘をつく理由はない。': 877,
#  'あなたに夢中なの。': 878,
#  'あなたに家にいてもらいたい。': 879,
#  'あなたに影響力はない。': 880,
#  'あなたに微笑んでいるのは誰ですか？': 881,
#  'あなたに応援をお願いしたくてここに来ました。': 882,
#  'あなたに恥をかかせるつもりはありませんでした。': 883,
#  'あなたに憧れてるの。': 884,
#  'あなたに折り入ってお話したいことがあるのですが。': 885,
#  'あなたに本をあげましょう。': 886,
#  'あなたに本当のことを言わなければならない時がやってきた。': 887,
#  'あなたに歌ってほしい。': 888,
#  'あなたに歌を歌ってもらいたい。': 889,
#  'あなたに献血は無理。': 890,
#  'あなたに私の家族の写真を送るつもりだ。': 891,
#  'あなたに話したいけど、でもできないの。': 892,
#  'あなたに返事をしなかったことを許してください。': 893,
#  'あなたに迷惑をかけたくありません。': 894,
#  'あなたのいう通りですよ。': 895,
#  'あなたのおかげです。': 896,
#  'あなたのおかげで私は幸せなのです。': 897,
#  'あなたのおじいちゃんはどこ？': 898,
#  'あなたのおじさんはどこ？': 899,
#  'あなたのおっしゃった事に興味を持ちました。': 900,
#  'あなたのおばあちゃんはどこ？': 901,
#  'あなたのお力添えにどれだけ感謝すればよいのか、言葉では言い表せません。': 902,
#  'あなたのお名前とお電話番号、いただけますか？': 903,
#  'あなたのお姉さんに会いたいです。': 904,
#  'あなたのお母さん、いい人そうね。': 905,
#  'あなたのお母さんって、一人っ子だった？': 906,
#  'あなたのお気に入りのスーパーヒーローは誰ですか。': 907,
#  'あなたのお気に入りのテレビ番組は何ですか。': 908,
#  'あなたのお気に入りのピアノ奏者はだれですか？': 909,
#  'あなたのお気に入りのフレンチワインは何？': 910,
#  'あなたのお父さんが何処に行ったか知っていますか。': 911,
#  'あなたのお父さんはおいくつですか。': 912,
#  'あなたのお父さんはとても背が高いですね。': 913,
#  'あなたのお父さんはどこにいますか。': 914,
#  'あなたのお父さんはどんな仕事をしてるの？': 915,
#  'あなたのお父さんはもういらっしゃいましたか？': 916,
#  'あなたのお父さんは何歳ですか。': 917,
#  'あなたのお父さんは背が高い。': 918,
#  'あなたのお父様にお会いできるのを楽しみにしています。': 919,
#  'あなたのお父様はどこにいらっしゃいますか？': 920,
#  'あなたのお爺さんはどこに住んでいますか。': 921,
#  'あなたのお薦めは何ですか。': 922,
#  'あなたのことが大好きです。': 923,
#  'あなたのことは全てわかっています。': 924,
#  'あなたのことをいろいろと考えていました。': 925,
#  'あなたのことをさして言っているのではない。': 926,
#  'あなたのことをまだ愛しています。': 927,
#  'あなたのことをよく知りません。': 928,
#  'あなたのことを忘れられません。': 929,
#  'あなたのこと好きじゃないの。': 930,
#  'あなたのこと好きだけど、恋愛対象ではないの。': 931,
#  'あなたのこと頼りにしていますよ。': 932,
#  'あなたのご親切にいくら感謝してもし過ぎることはない。': 933,
#  'あなたのご親切は一生忘れません。': 934,
#  'あなたのご親切をとてもありがたいと思います。': 935,
#  'あなたのご親切を私はけっして忘れません。': 936,
#  'あなたのすぐ後ろにいたよ。': 937,
#  'あなたのせいではありません。': 938,
#  'あなたのそういうところ、お父さんにそっくりね。': 939,
#  'あなたのその話し方は、いつかトラブルを招くことになりますよ。': 940,
#  'あなたのためなら喜んでどんなことでもします。': 941,
#  'あなたのためにしました。': 942,
#  'あなたのためにやったわけではありません。': 943,
#  'あなたのばかげた振る舞いがなかったら、私たちはあんな面倒にあわなかったろうに。': 944,
#  'あなたのような人を助けるのが私の仕事です。': 945,
#  'あなたのアカウントは一時的にロックされています。': 946,
#  'あなたのアドバイスが必要なんです。': 947,
#  'あなたのアドバイスにはいつも助けられています。': 948,
#  'あなたのアドバイスはいつも私の助けになりました。': 949,
#  'あなたのアルバムを見せてくれる？': 950,
#  'あなたのイチゴ食べちゃった。': 951,
#  'あなたのクラスには何人の生徒がいますか。': 952,
#  'あなたのクレジットカードはどこにありますか。': 953,
#  'あなたのコーヒー代、私に払わせてください。': 954,
#  'あなたのサインをいただけませんか。': 955,
#  'あなたのシャツ、いいですね。': 956,
#  'あなたのスカートは時代遅れですよ。': 957,
#  'あなたのスピーチはあの場にふさわしいものだった。': 958,
#  'あなたのスピーチは合格点から程遠いものです。': 959,
#  'あなたのスーツケース、運んであげますよ。': 960,
#  'あなたのスーツケースの重さはどれぐらいですか？': 961,
#  'あなたのバンドに入りたいな。': 962,
#  'あなたのフランス語を向上させる機会になるだろうと思いました。': 963,
#  'あなたのフルネームは何ですか？': 964,
#  'あなたのベッドの下でこれを見つけました。': 965,
#  'あなたのページから、私どもの会社のサイトへリンクしていただけませんか。': 966,
#  'あなたのページに、私どもの会社のウェブリンクを貼り付けていただけませんか。': 967,
#  'あなたの一押しの俳優は誰ですか？': 968,
#  'あなたの一番好きなテレビタレントはだれ？': 969,
#  'あなたの一番好きな映画は何ですか。': 970,
#  'あなたの体験を教えて。': 971,
#  'あなたの作品の見本をいくつか見せてくれませんか。': 972,
#  'あなたの健康が心配です。': 973,
#  'あなたの傘はどこ？': 974,
#  'あなたの写真を撮ってもいいですか。': 975,
#  'あなたの写真を申込書に添付することが必要だ。': 976,
#  'あなたの初恋はいつでしたか。': 977,
#  'あなたの判断にお任せします。': 978,
#  'あなたの助けが本当に必要なんです。': 979,
#  'あなたの助けが無ければそれはできなかったでしょう。': 980,
#  'あなたの助けは必要なかった。': 981,
#  'あなたの努力はいつか実を結ぶだろう。': 982,
#  'あなたの勉強を邪魔しないようにします。': 983,
#  'あなたの友だちによろしく。': 984,
#  'あなたの友だちは何時に帰りましたか？': 985,
#  'あなたの友達がCIAにいると聞いています。': 986,
#  'あなたの友達って誰？': 987,
#  'あなたの友達の名前は何ですか。': 988,
#  'あなたの口座の残高はゼロだ。': 989,
#  'あなたの口座は空っぽだ。': 990,
#  'あなたの古いMP3プレイヤーの購入にトムが興味を示す見込みはないと思う。': 991,
#  'あなたの名前に聞き覚えがあります。': 992,
#  'あなたの名前のスペルはなんですか？': 993,
#  'あなたの名前のスペルを教えてもらえませんか?': 994,
#  'あなたの名前はトムなの？': 995,
#  'あなたの名前は？': 996,
#  'あなたの唇きれいね。': 997,
#  'あなたの問題は私の問題と似ています。': 998,
#  'あなたの国では米を食べますか？': 999,
#  ...}

# %%
jap_index_word = dict((i, w) for i, w in enumerate(jap_words))
eng_index_word = dict((i,w) for i, w in enumerate(eng_words))

# %%
eng_index_word
# Out:
# {0: '"4',
#  1: '"About',
#  2: '"Actually,',
#  3: '"All',
#  4: '"And',
#  5: '"Anytime',
#  6: '"Anywhere',
#  7: '"Are',
#  8: '"At',
#  9: '"Because',
#  10: '"Beispiel?"',
#  11: '"By',
#  12: '"Certainly',
#  13: '"Certainly."',
#  14: '"Could',
#  15: '"Do',
#  16: '"Don\'t',
#  17: '"Everything."',
#  18: '"For',
#  19: '"Forgotten',
#  20: '"French."',
#  21: '"Friendship".',
#  22: '"Get',
#  23: '"Go',
#  24: '"He',
#  25: '"Here',
#  26: '"Hold',
#  27: '"How',
#  28: '"I',
#  29: '"I\'d',
#  30: '"I\'ll',
#  31: '"I\'m',
#  32: '"I\'ve',
#  33: '"If',
#  34: '"In',
#  35: '"Is',
#  36: '"It',
#  37: '"It\'s',
#  38: '"It\'s"',
#  39: '"Itch."',
#  40: '"Jailhouse',
#  41: '"Just',
#  42: '"Keep',
#  43: '"Let\'s',
#  44: '"Me',
#  45: '"Me,',
#  46: '"Neither',
#  47: '"No',
#  48: '"No,',
#  49: '"Not',
#  50: '"Nothing',
#  51: '"Nothing."',
#  52: '"OK."',
#  53: '"Of',
#  54: '"Oh,',
#  55: '"On',
#  56: '"Only',
#  57: '"Pretty',
#  58: '"Rain,',
#  59: '"Really?"',
#  60: '"She',
#  61: '"She\'s',
#  62: '"So',
#  63: '"Sorry,',
#  64: '"Stay',
#  65: '"Stop',
#  66: '"Sure',
#  67: '"Sure!"',
#  68: '"Sure,',
#  69: '"Sure.',
#  70: '"Sure."',
#  71: '"Talking',
#  72: '"That',
#  73: '"That\'s',
#  74: '"The',
#  75: '"Then',
#  76: '"There',
#  77: '"There\'s',
#  78: '"They',
#  79: '"Three,',
#  80: '"Tom',
#  81: '"War',
#  82: '"We',
#  83: '"What?',
#  84: '"What?"',
#  85: '"Why',
#  86: '"Wi-Fi"',
#  87: '"Will',
#  88: '"Wow!',
#  89: '"Yeah,',
#  90: '"Yes,',
#  91: '"Yes.',
#  92: '"Yes."',
#  93: '"You',
#  94: '"You\'ll',
#  95: '"You\'re',
#  96: '"aah."',
#  97: '"anglophobia,"',
#  98: '"baby',
#  99: '"biotechnology"',
#  100: '"bonjour."',
#  101: '"for',
#  102: '"good',
#  103: '"he"',
#  104: '"hello."',
#  105: '"its"',
#  106: '"kairanban,"',
#  107: '"kaisha"',
#  108: '"little',
#  109: '"michi"',
#  110: '"no',
#  111: '"no."',
#  112: '"oddball"',
#  113: '"password"',
#  114: '"resident',
#  115: '"s."',
#  116: '"senior',
#  117: '"she"',
#  118: '"shiitake"',
#  119: '"slow."',
#  120: '"subway",',
#  121: '"thank',
#  122: '"triangle."',
#  123: '"underground".',
#  124: '"yes,"',
#  125: '"you',
#  126: '"yuri"',
#  127: '$1',
#  128: '$1,000',
#  129: '$1,000.',
#  130: '$1.00',
#  131: '$10,000',
#  132: '$10,000.',
#  133: '$10.',
#  134: '$10.00!',
#  135: '$100',
#  136: '$100,000',
#  137: '$13,',
#  138: '$2,000.',
#  139: '$200',
#  140: '$30,',
#  141: '$30.',
#  142: '$300',
#  143: '$30?',
#  144: '$314',
#  145: '$33.',
#  146: '$5.',
#  147: '$50',
#  148: '$50.',
#  149: '$500',
#  150: '$68.9',
#  151: '$7,000.',
#  152: '$7.65,',
#  153: '$77.0',
#  154: '$77.8',
#  155: "'Australia?'",
#  156: "'Madame",
#  157: "'em.",
#  158: "'gold'",
#  159: '(!),',
#  160: '(.),',
#  161: '(?).',
#  162: '--',
#  163: '...',
#  164: '0',
#  165: '0.',
#  166: '0120-00-0000.',
#  167: '1',
#  168: '1,',
#  169: '1,000',
#  170: '1,500',
#  171: '1,600',
#  172: '1,825',
#  173: '1.',
#  174: '10',
#  175: '10%',
#  176: '10,',
#  177: '10,000',
#  178: '10-minute',
#  179: '10.',
#  180: '100',
#  181: '100%',
#  182: '100,000.',
#  183: '100.',
#  184: '100?',
#  185: '102',
#  186: '105.',
#  187: '105?',
#  188: '1066.',
#  189: '10:00',
#  190: '10:00.',
#  191: '10:00?',
#  192: '10:30',
#  193: '10:30.',
#  194: '10:40',
#  195: '10?',
#  196: '10th',
#  197: '11',
#  198: '11.',
#  199: '110',
#  200: '110.',
#  201: '111?',
#  202: '119.',
#  203: '11:00',
#  204: '11:00.',
#  205: '11:30',
#  206: '11:45.',
#  207: '11th',
#  208: '12',
#  209: '12,',
#  210: '12.5%',
#  211: '120',
#  212: '120!',
#  213: '123',
#  214: '124?',
#  215: '12:45?',
#  216: '12th',
#  217: '13',
#  218: '13-year-old',
#  219: '13.',
#  220: '13th',
#  221: '14%',
#  222: '1492.',
#  223: '1499.',
#  224: '14th,',
#  225: '15',
#  226: '15.',
#  227: '150',
#  228: '150,000',
#  229: '150?',
#  230: '155',
#  231: '15th',
#  232: '16',
#  233: '16.',
#  234: '160',
#  235: '1600',
#  236: '1600s,',
#  237: '1603,',
#  238: '1603.',
#  239: '1636.',
#  240: '1642.',
#  241: '1650.',
#  242: '1689.',
#  243: '16th',
#  244: '17',
#  245: '17,',
#  246: '17.',
#  247: '17th',
#  248: '18',
#  249: '18.',
#  250: '180',
#  251: '1806.',
#  252: '182,620',
#  253: '1820',
#  254: '1840s.',
#  255: '1843.',
#  256: '1847,',
#  257: '1853,',
#  258: '1853.',
#  259: '1860,',
#  260: '1860.',
#  261: '1865.',
#  262: '1888.',
#  263: '18?',
#  264: '19',
#  265: '19,',
#  266: '19.',
#  267: '1906,',
#  268: '1910.',
#  269: '1912',
#  270: '1912.',
#  271: '1914,',
#  272: '1914.',
#  273: '1920s',
#  274: '1927.',
#  275: "1930's,",
#  276: '1932',
#  277: '1939',
#  278: '1939,',
#  279: '1939.',
#  280: '1941.',
#  281: '1943,',
#  282: '1945.',
#  283: '1946,',
#  284: '1946.',
#  285: '1947.',
#  286: '1949.',
#  287: '1950.',
#  288: '1950s.',
#  289: '1951,',
#  290: '1952.',
#  291: '1954.',
#  292: '1955,',
#  293: '1955.',
#  294: '1956',
#  295: '1957.',
#  296: '1958,',
#  297: '1959,',
#  298: "1960's,",
#  299: "1960's.",
#  300: '1960.',
#  301: '1962,',
#  302: '1964,',
#  303: '1968,',
#  304: '1968.',
#  305: "1970's,",
#  306: '1970.',
#  307: '1970s.',
#  308: '1973,',
#  309: '1974.',
#  310: '1976.',
#  311: '1977.',
#  312: '1978',
#  313: '1979,',
#  314: '1979.',
#  315: '1980',
#  316: '1980.',
#  317: '1982.',
#  318: '1983',
#  319: '1983,',
#  320: '1987.',
#  321: '1988.',
#  322: '1989',
#  323: '1990.',
#  324: '1990?',
#  325: '1990s',
#  326: '1992',
#  327: '1992.',
#  328: '1994,',
#  329: '1997,',
#  330: '1998,',
#  331: '1998.',
#  332: '1999.',
#  333: '19th',
#  334: '1:35.',
#  335: '1st',
#  336: '1st,',
#  337: '1st.',
#  338: '2',
#  339: '2,',
#  340: '2,000',
#  341: '2,500',
#  342: '2.',
#  343: '20',
#  344: '20%',
#  345: '20,',
#  346: '20,000',
#  347: '20.',
#  348: '200',
#  349: '2001.',
#  350: '2003.',
#  351: '2006.',
#  352: '2009,',
#  353: '2011',
#  354: '2013',
#  355: '2013.',
#  356: '2013?',
#  357: '2015.',
#  358: '2020,',
#  359: '20s',
#  360: '20th',
#  361: '20th.',
#  362: '21',
#  363: '212-836-1725.',
#  364: '213.',
#  365: '21st',
#  366: '22,',
#  367: '22.',
#  368: '22.68',
#  369: '223-1374?',
#  370: '226',
#  371: '22nd.',
#  372: '24,',
#  373: '24th',
#  374: '25',
#  375: '25%',
#  376: '25,',
#  377: '25.',
#  378: '25th.',
#  379: '26',
#  380: '26,',
#  381: '26.',
#  382: '27',
#  383: '27.',
#  384: '270',
#  385: '27th.',
#  386: '28',
#  387: '28,',
#  388: '28th,',
#  389: '29th.',
#  390: '2:00.',
#  391: '2:30',
#  392: '2:30.',
#  393: '2:30."',
#  394: '2:30?',
#  395: '3',
#  396: '3,',
#  397: '3,000',
#  398: '3,776',
#  399: '3.',
#  400: '3.4',
#  401: '30',
#  402: '30%',
#  403: '30,000',
#  404: '30.',
#  405: '300',
#  406: '300,000',
#  407: '305?',
#  408: '30?',
#  409: '30th',
#  410: '30th.',
#  411: '31.',
#  412: '32',
#  413: '330',
#  414: '33?',
#  415: '34.',
#  416: '35',
#  417: '360',
#  418: '360?',
#  419: '38',
#  420: '38,',
#  421: '3:00',
#  422: '3:00.',
#  423: '3:20."',
#  424: '3:30.',
#  425: '4',
#  426: '4,',
#  427: '4,000',
#  428: '4,219',
#  429: '4.',
#  430: '40',
#  431: '40.',
#  432: '400',
#  433: '400,000',
#  434: '40th',
#  435: '42',
#  436: '42.',
#  437: '42nd',
#  438: '442-5511.',
#  439: '45',
#  440: '45-cent',
#  441: '450',
#  442: '46',
#  443: '4:00',
#  444: '4:10',
#  445: '4:30',
#  446: '4th',
#  447: '5',
#  448: '5%',
#  449: '5%.',
#  450: '5,',
#  451: '5,000',
#  452: '5,500',
#  453: '5,814',
#  454: '5.',
#  455: '5.0',
#  456: '50',
#  457: '50,000',
#  458: '500',
#  459: '500,000',
#  460: '54',
#  461: '54.',
#  462: '56',
#  463: '57?',
#  464: '58',
#  465: '58.',
#  466: '5:00',
#  467: '5?',
#  468: '5th',
#  469: '5th.',
#  470: '6',
#  471: '6%.',
#  472: '6.',
#  473: '60',
#  474: '60?',
#  475: '60th',
#  476: '65.',
#  477: '66',
#  478: '6:00',
#  479: '6:00,',
#  480: '6:00.',
#  481: '6:30',
#  482: '6:30,',
#  483: '6:30.',
#  484: '6th',
#  485: '7',
#  486: '7,',
#  487: '7.',
#  488: '70',
#  489: '70,000',
#  490: '70.',
#  491: '75',
#  492: '7:00',
#  493: '7:00.',
#  494: '7:30',
#  495: '7:30.',
#  496: '7:45.',
#  497: '7th',
#  498: '7th.',
#  499: '8',
#  500: '8.',
#  501: '80,000',
#  502: '80-yen',
#  503: '82',
#  504: '83.',
#  505: '839.',
#  506: '86.',
#  507: '88th',
#  508: '8:00',
#  509: '8:00.',
#  510: '8:15',
#  511: '8:30',
#  512: '8:30.',
#  513: '8th',
#  514: '9',
#  515: '9.',
#  516: '90',
#  517: '90%',
#  518: '91',
#  519: '911.',
#  520: '92',
#  521: '95',
#  522: '97',
#  523: '97.',
#  524: '98',
#  525: '9:00',
#  526: '9:00.',
#  527: '9:00?',
#  528: '9:15.',
#  529: '9:20',
#  530: '9:30',
#  531: 'A',
#  532: 'ABC',
#  533: 'AGAIN!',
#  534: 'AI',
#  535: 'AIDS',
#  536: 'ALS',
#  537: 'ATM',
#  538: 'ATM.',
#  539: 'About',
#  540: 'Above',
#  541: 'Abraham',
#  542: 'Absence',
#  543: 'Accidents',
#  544: 'According',
#  545: 'Accuracy',
#  546: 'Act',
#  547: 'Actions',
#  548: 'Actually,',
#  549: 'Add',
#  550: 'Adding',
#  551: 'Address',
#  552: 'Adjust',
#  553: 'Admission',
#  554: 'Admittedly',
#  555: 'Advance',
#  556: 'Afghanistan.',
#  557: 'Africa',
#  558: 'Africa.',
#  559: 'Africa?',
#  560: 'African',
#  561: 'After',
#  562: 'Agency.',
#  563: 'Ah',
#  564: 'Aichi',
#  565: 'Aikido',
#  566: 'Air',
#  567: 'Airlines',
#  568: 'Airplanes',
#  569: 'Airport',
#  570: 'Akagi',
#  571: 'Akita',
#  572: 'Akutagawa,',
#  573: 'Alabama,',
#  574: 'Alaska.',
#  575: 'Albert',
#  576: 'Alexandria?',
#  577: 'Algebra',
#  578: 'Algeria',
#  579: 'Alice',
#  580: 'Alice,',
#  581: 'Alice.',
#  582: 'Alice?',
#  583: 'All',
#  584: "All's",
#  585: 'Allow',
#  586: 'Almost',
#  587: 'Alps',
#  588: 'Although',
#  589: 'Aluminum',
#  590: 'Always',
#  591: 'Am',
#  592: 'Amazon',
#  593: 'Amazon.com.',
#  594: 'Ambassador',
#  595: 'America',
#  596: "America's",
#  597: 'America,',
#  598: 'America.',
#  599: 'America?',
#  600: 'American',
#  601: 'American.',
#  602: 'American?',
#  603: 'Americanized',
#  604: 'Americans',
#  605: 'Americans.',
#  606: 'Amnesty',
#  607: 'Among',
#  608: 'Amuro.',
#  609: 'An',
#  610: 'Ancient',
#  611: 'And',
#  612: 'Angeles',
#  613: 'Angeles.',
#  614: 'Anglo-Saxons',
#  615: 'Angola',
#  616: 'Animals',
#  617: 'Ankara',
#  618: 'Ankara.',
#  619: 'Another',
#  620: 'Answer',
#  621: 'Ants',
#  622: 'Any',
#  623: 'Anybody',
#  624: 'Anyhow,',
#  625: 'Anyone',
#  626: 'Anything',
#  627: 'Anyway,',
#  628: 'Anywhere',
#  629: 'Apart',
#  630: 'Apes',
#  631: 'Apollo',
#  632: 'Apparently',
#  633: 'Apparently,',
#  634: 'Apples',
#  635: 'Apply',
#  636: 'April',
#  637: 'April.',
#  638: 'Arab',
#  639: 'Arabic',
#  640: 'Arabic.',
#  641: 'Arctic.',
#  642: 'Are',
#  643: "Aren't",
#  644: 'Ariake',
#  645: 'Arlington',
#  646: 'Armenia',
#  647: 'Armstrong',
#  648: 'Around',
#  649: 'Artificial',
#  650: 'As',
#  651: 'Asahi',
#  652: 'Asama',
#  653: 'Asia.',
#  654: 'Asian',
#  655: 'Asians.',
#  656: 'Ask',
#  657: 'Asking',
#  658: 'At',
#  659: 'Atlantic',
#  660: 'Atlantic.',
#  661: 'Atoms',
#  662: 'Attach',
#  663: 'Attend',
#  664: 'Attention',
#  665: 'August',
#  666: 'August.',
#  667: 'Australia',
#  668: "Australia's",
#  669: 'Australia,',
#  670: 'Australia.',
#  671: 'Australia?',
#  672: 'Australian',
#  673: 'Austria',
#  674: 'Austria,',
#  675: 'Autumn',
#  676: 'Avenue.',
#  677: 'Avoid',
#  678: 'Awesome!',
#  679: 'B',
#  680: 'B.',
#  681: 'BBQ',
#  682: 'Babies',
#  683: 'Back',
#  684: 'Bacteria',
#  685: 'Bad',
#  686: 'Bagdad.',
#  687: 'Baker',
#  688: 'Bali',
#  689: 'Balls',
#  690: 'Bananas',
#  691: 'Band-Aid',
#  692: 'Bangkok',
#  693: 'Bank',
#  694: 'Banks',
#  695: 'Barcelona',
#  696: 'Barking',
#  697: 'Barley',
#  698: 'Baroque',
#  699: 'Bartender,',
#  700: 'Basho',
#  701: 'Basically,',
#  702: 'Basin',
#  703: 'Basketball',
#  704: 'Battle',
#  705: 'Bay',
#  706: 'Be',
#  707: 'Beaches',
#  708: 'Bear',
#  709: 'Bears',
#  710: 'Beat',
#  711: 'Beating',
#  712: 'Beatles',
#  713: 'Beatles.',
#  714: 'Beatles?',
#  715: 'Beautiful',
#  716: 'Beauty',
#  717: 'Because',
#  718: 'Beef',
#  719: 'Beef,',
#  720: 'Beer',
#  721: 'Bees',
#  722: 'Beethoven',
#  723: 'Before',
#  724: 'Beggars',
#  725: 'Begin',
#  726: 'Beginning',
#  727: 'Behave',
#  728: 'Beijing.',
#  729: 'Being',
#  730: 'Belgium.',
#  731: 'Believe',
#  732: 'Bell',
#  733: 'Bell.',
#  734: 'Benjamin',
#  735: 'Berlin',
#  736: 'Berlin?',
#  737: 'Besides',
#  738: 'Better',
#  739: 'Between',
#  740: 'Beware',
#  741: 'Bible.',
#  742: 'Bicycles',
#  743: 'Big',
#  744: 'Birds',
#  745: 'Biwa',
#  746: 'Biwa.',
#  747: 'Black',
#  748: 'Blanc?',
#  749: 'Blondie,',
#  750: 'Blood',
#  751: 'Blow',
#  752: 'Blue',
#  753: 'Blues',
#  754: 'Board',
#  755: 'Boeing',
#  756: 'Boil',
#  757: 'Bonds',
#  758: 'Bookmark',
#  759: 'Books',
#  760: 'Bookstore.',
#  761: 'Boston',
#  762: 'Boston,',
#  763: 'Boston.',
#  764: 'Boston?',
#  765: 'Both',
#  766: 'Bottoms',
#  767: 'Boys',
#  768: 'Boys,',
#  769: 'Boy”',
#  770: 'Brasilia.',
#  771: 'Brazil',
#  772: 'Brazil.',
#  773: 'Breakfast',
#  774: 'Breathe',
#  775: 'Bricks',
#  776: 'Bridge.',
#  777: 'Bridge?',
#  778: 'Bring',
#  779: 'Britain',
#  780: 'Britain.',
#  781: 'Britain?',
#  782: 'British',
#  783: 'Broccoli',
#  784: 'Broken',
#  785: 'Brokers',
#  786: 'Brush',
#  787: 'Buckingham',
#  788: 'Buckle',
#  789: 'Buddha',
#  790: 'Buddhism',
#  791: 'Buddhist',
#  792: 'Building',
#  793: 'Buildings',
#  794: 'Bunyan?',
#  795: 'Burn',
#  796: 'Bush',
#  797: 'Business',
#  798: 'But',
#  799: 'But,',
#  800: 'Butter',
#  801: 'Butterflies',
#  802: "Butterfly'",
#  803: 'Buy',
#  804: 'By',
#  805: 'C',
#  806: 'C.',
#  807: 'CD',
#  808: 'CD,',
#  809: 'CD.',
#  810: 'CD?',
#  811: 'CDs',
#  812: 'CEO.',
#  813: 'CIA.',
#  814: 'CIA?',
#  815: 'CO2',
#  816: 'CO₂',
#  817: 'Caesar,',
#  818: 'Cairo',
#  819: 'Cairo.',
#  820: 'Calcutta,',
#  821: 'California',
#  822: 'California.',
#  823: 'Call',
#  824: 'Calm',
#  825: 'Cambridge',
#  826: 'Camels',
#  827: 'Can',
#  828: "Can't",
#  829: 'Canada',
#  830: 'Canada,',
#  831: 'Canada.',
#  832: 'Canada?',
#  833: 'Canadian',
#  834: 'Canadian,',
#  835: 'Canadian.',
#  836: 'Canadian?',
#  837: 'Canadians',
#  838: 'Canadians,',
#  839: 'Canadians.',
#  840: 'Canadians?',
#  841: 'Canal',
#  842: 'Canal.',
#  843: 'Canary',
#  844: 'Cancer',
#  845: 'Candy.',
#  846: 'Canyon',
#  847: 'Careful',
#  848: 'Carnegie',
#  849: 'Carrots',
#  850: 'Carry',
#  851: 'Cars',
#  852: 'Cassette',
#  853: 'Castro',
#  854: 'Catalonia,',
#  855: 'Catch',
#  856: 'Catholic',
#  857: 'Catholic.',
#  858: 'Catholics',
#  859: 'Cats',
#  860: 'Cattle',
#  861: 'Celsius.',
#  862: 'Cemetery.',
#  863: 'Center',
#  864: 'Center?',
#  865: 'Centigrade.',
#  866: 'Certain',
#  867: 'Chamberlain',
#  868: 'Champagne,',
#  869: 'Chances',
#  870: 'Change',
#  871: 'Changing',
#  872: 'Channel',
#  873: 'Channel.',
#  874: 'Chapter',
#  875: 'Charge',
#  876: 'Charles',
#  877: 'Check',
#  878: 'Check,',
#  879: 'Cheer',
#  880: 'Cheers!',
#  881: 'Cheese',
#  882: 'Cherries',
#  883: 'Cherry',
#  884: 'Chew',
#  885: 'Chi',
#  886: 'Chiba',
#  887: 'Chicago',
#  888: 'Chicago.',
#  889: 'Chicago?',
#  890: 'Chicken',
#  891: 'Children',
#  892: "Children's",
#  893: 'Chile.',
#  894: 'Chill',
#  895: 'China',
#  896: 'China.',
#  897: 'Chinatown?',
#  898: 'Chinese',
#  899: 'Chinese,',
#  900: 'Chinese-Japanese',
#  901: 'Chinese.',
#  902: 'Chinese?',
#  903: 'Choose',
#  904: 'Chopin',
#  905: 'Chopin.',
#  906: 'Christian.',
#  907: 'Christian?',
#  908: 'Christianity',
#  909: 'Christianity.',
#  910: 'Christmas',
#  911: 'Christmas!',
#  912: 'Christmas.',
#  913: 'Christmas?',
#  914: 'Church',
#  915: 'Cities',
#  916: 'Citizens',
#  917: 'City',
#  918: 'City.',
#  919: 'Class',
#  920: 'Classes',
#  921: 'Classical',
#  922: 'Claus',
#  923: 'Claus.',
#  924: 'Claus?',
#  925: 'Clean',
#  926: 'Clearly,',
#  927: "Cleopatra's",
#  928: 'Clinton',
#  929: 'Close',
#  930: 'Coal',
#  931: 'Coast',
#  932: 'Coca-Cola.',
#  933: 'Cockroaches',
#  934: 'Coffee',
#  935: 'Coffee,',
#  936: 'Coffee?',
#  937: 'Coincidentally',
#  938: 'Coke',
#  939: 'Cold',
#  940: 'Cold-war',
#  941: 'Colds',
#  942: 'Columbo',
#  943: 'Columbus',
#  944: 'Comb',
#  945: 'Come',
#  946: 'Common',
#  947: 'Communications',
#  948: 'Communists',
#  949: 'Compare',
#  950: 'Compared',
#  951: 'Compasses',
#  952: 'Competition',
#  953: 'Competition.',
#  954: 'Compiling',
#  955: 'Complaining',
#  956: 'Computer',
#  957: 'Computers',
#  958: 'Concentrate',
#  959: 'Congratulations!',
#  960: 'Congress.',
#  961: 'Connecticut',
#  962: 'Consider',
#  963: 'Construction',
#  964: 'Contact',
#  965: 'Cook',
#  966: 'Cookie',
#  967: "Cookie's",
#  968: 'Cookie.',
#  969: 'Cooking',
#  970: 'Cool',
#  971: 'Copenhagen',
#  972: 'Copy',
#  973: 'Correct',
#  974: 'Could',
#  975: "Couldn't",
#  976: 'Count',
#  977: 'Countless',
#  978: 'Country',
#  979: 'Court',
#  980: 'Cover',
#  981: 'Covered',
#  982: 'Cows',
#  983: 'Crime',
#  984: 'Crimes',
#  985: 'Cross',
#  986: 'Cross.',
#  987: 'Crows',
#  988: 'Crude',
#  989: 'Crying',
#  990: 'Cuba',
#  991: 'Cucumbers',
#  992: 'Cue',
#  993: 'Cup',
#  994: 'Currently,',
#  995: 'Customs',
#  996: 'Customs?',
#  997: 'Cut',
#  998: 'Cutting',
#  999: 'D',
#  ...}

# %%
X_train, X_test, y_train, y_test= train_test_split(df.Japanese, df.English, test_size=0.1, random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((56238,), (6249,), (56238,), (6249,))

# %%
jap_len_list=df.Japanese.apply(lambda x: len(x.split())).to_list()

eng_len_list=df.English.apply(lambda x: len(x.split())).to_list()

# %%
np.max(eng_len_list), np.max(jap_len_list)
# Out:
# (44, 10)

# %%
BATCH_SIZE= 64
max_jap_len =  np.max(jap_len_list)
max_eng_len =  np.max(eng_len_list)

# %%
max_jap_len, max_eng_len
# Out:
# (10, 44)

# %%
def data_batch_generator(x, y, batch_size=BATCH_SIZE):
    while True:
        for i in range(0, len(x), batch_size):
            encoder_input_data = np.zeros((batch_size,max_jap_len ), dtype='float32')
            decoder_input_data = np.zeros((batch_size, max_eng_len), dtype='float32')
            decoder_target_data = np.zeros((batch_size, max_eng_len, ENG_VOCAB_SIZE), dtype='float32' )
            for j, (jap_text, eng_text) in enumerate(zip(x[i:i+batch_size], y[i:i+batch_size])):
                for t , word in enumerate(jap_text.split()):
                    encoder_input_data[j,t] = jap_word_index[word]
                for t, word in enumerate(eng_text.split()):
                    if t < len(eng_text.split()) - 1:
                        decoder_input_data[j,t]= eng_word_index[word]
                    if t>0:
                    
                        decoder_target_data[j,t-1, eng_word_index[word]] = 1.
            yield ([encoder_input_data, decoder_input_data], decoder_target_data)

# %%
from tensorflow.keras.layers import LSTM, Dropout, Dense, Embedding
from tensorflow.keras import Input, Model

# %%
# Eoncoder
encoder_input = Input(shape=(None, ))
encoder_embd = Embedding(JAP_VOCAB_SIZE,100, mask_zero=True)(encoder_input)
encoder_lstm = LSTM(100, return_state=True)
encoder_output,state_h, state_c = encoder_lstm(encoder_embd)

encoder_states= [state_h, state_c]

# Decoder
decoder_input = Input(shape=(None,))
decoder_embd = Embedding(ENG_VOCAB_SIZE, 100, mask_zero=True)
decoder_embedding= decoder_embd(decoder_input)
decoder_lstm = LSTM(100, return_state=True,return_sequences=True )
decoder_outputs, _, _= decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense= Dense(ENG_VOCAB_SIZE, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

model1 = Model([encoder_input, decoder_input], decoder_outputs)

# %%
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics='accuracy')

# %%
checkpoint = ModelCheckpoint("/content/drive/MyDrive/Bhomik - Copy/model_checkpoints/", monitor='val_accuracy')

early_stopping = EarlyStopping(monitor='val_accuracy', patience=5)

callbacks_list = [checkpoint, early_stopping]

# %%
steps_per_epoch= np.ceil(len(X_train)/BATCH_SIZE)
steps_per_epoch_val = np.ceil(len(X_train)/BATCH_SIZE)

# %%
steps_per_epoch
# Out:
# 879.0

# %%
EPOCHS= 30 #@param {type:'slider',min:10,max:100, step:10 }
EPOCHS
# Out:
# 30

# %%
history1= model1.fit(data_batch_generator(X_train,y_train), 
                       epochs=EPOCHS,
                       steps_per_epoch= steps_per_epoch,
                     validation_data=data_batch_generator(X_test, y_test, BATCH_SIZE),
                       validation_steps=steps_per_epoch_val,
                     callbacks=callbacks_list)
# Out:
# Epoch 1/30
# 879/879 [==============================] - ETA: 0s - loss: 0.8545 - accuracy: 0.0699
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 317s 348ms/step - loss: 0.8545 - accuracy: 0.0699 - val_loss: 0.7939 - val_accuracy: 0.1010
# Epoch 2/30
# 879/879 [==============================] - ETA: 0s - loss: 0.7440 - accuracy: 0.1242
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 300s 342ms/step - loss: 0.7440 - accuracy: 0.1242 - val_loss: 0.7357 - val_accuracy: 0.1374
# Epoch 3/30
# 879/879 [==============================] - ETA: 0s - loss: 0.6912 - accuracy: 0.1537
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 307s 349ms/step - loss: 0.6912 - accuracy: 0.1537 - val_loss: 0.7032 - val_accuracy: 0.1577
# Epoch 4/30
# 879/879 [==============================] - ETA: 0s - loss: 0.6554 - accuracy: 0.1721
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 304s 346ms/step - loss: 0.6554 - accuracy: 0.1721 - val_loss: 0.6823 - val_accuracy: 0.1712
# Epoch 5/30
# 879/879 [==============================] - ETA: 0s - loss: 0.6248 - accuracy: 0.1894
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 305s 347ms/step - loss: 0.6248 - accuracy: 0.1894 - val_loss: 0.6687 - val_accuracy: 0.1791
# Epoch 6/30
# 879/879 [==============================] - ETA: 0s - loss: 0.5980 - accuracy: 0.2065
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 304s 346ms/step - loss: 0.5980 - accuracy: 0.2065 - val_loss: 0.6588 - val_accuracy: 0.1846
# Epoch 7/30
# 879/879 [==============================] - ETA: 0s - loss: 0.5743 - accuracy: 0.2220
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 305s 347ms/step - loss: 0.5743 - accuracy: 0.2220 - val_loss: 0.6517 - val_accuracy: 0.1888
# Epoch 8/30
# 879/879 [==============================] - ETA: 0s - loss: 0.5530 - accuracy: 0.2357
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 305s 348ms/step - loss: 0.5530 - accuracy: 0.2357 - val_loss: 0.6471 - val_accuracy: 0.1883
# Epoch 9/30
# 879/879 [==============================] - ETA: 0s - loss: 0.5337 - accuracy: 0.2481
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 311s 354ms/step - loss: 0.5337 - accuracy: 0.2481 - val_loss: 0.6434 - val_accuracy: 0.1913
# Epoch 10/30
# 879/879 [==============================] - ETA: 0s - loss: 0.5151 - accuracy: 0.2608
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 311s 354ms/step - loss: 0.5151 - accuracy: 0.2608 - val_loss: 0.6421 - val_accuracy: 0.1943
# Epoch 11/30
# 879/879 [==============================] - ETA: 0s - loss: 0.4964 - accuracy: 0.2754
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 312s 355ms/step - loss: 0.4964 - accuracy: 0.2754 - val_loss: 0.6428 - val_accuracy: 0.1962
# Epoch 12/30
# 879/879 [==============================] - ETA: 0s - loss: 0.4781 - accuracy: 0.2923
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 312s 355ms/step - loss: 0.4781 - accuracy: 0.2923 - val_loss: 0.6437 - val_accuracy: 0.1996
# Epoch 13/30
# 879/879 [==============================] - ETA: 0s - loss: 0.4605 - accuracy: 0.3095
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 314s 357ms/step - loss: 0.4605 - accuracy: 0.3095 - val_loss: 0.6448 - val_accuracy: 0.2017
# Epoch 14/30
# 879/879 [==============================] - ETA: 0s - loss: 0.4438 - accuracy: 0.3271
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 315s 358ms/step - loss: 0.4438 - accuracy: 0.3271 - val_loss: 0.6498 - val_accuracy: 0.2005
# Epoch 15/30
# 879/879 [==============================] - ETA: 0s - loss: 0.4278 - accuracy: 0.3442
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 316s 360ms/step - loss: 0.4278 - accuracy: 0.3442 - val_loss: 0.6513 - val_accuracy: 0.2038
# Epoch 16/30
# 879/879 [==============================] - ETA: 0s - loss: 0.4129 - accuracy: 0.3610
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 315s 359ms/step - loss: 0.4129 - accuracy: 0.3610 - val_loss: 0.6578 - val_accuracy: 0.2033
# Epoch 17/30
# 879/879 [==============================] - ETA: 0s - loss: 0.3987 - accuracy: 0.3781
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 317s 361ms/step - loss: 0.3987 - accuracy: 0.3781 - val_loss: 0.6626 - val_accuracy: 0.2040
# Epoch 18/30
# 879/879 [==============================] - ETA: 0s - loss: 0.3850 - accuracy: 0.3953
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 315s 358ms/step - loss: 0.3850 - accuracy: 0.3953 - val_loss: 0.6646 - val_accuracy: 0.2073
# Epoch 19/30
# 879/879 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.4126
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 316s 360ms/step - loss: 0.3711 - accuracy: 0.4126 - val_loss: 0.6721 - val_accuracy: 0.2056
# Epoch 20/30
# 879/879 [==============================] - ETA: 0s - loss: 0.3576 - accuracy: 0.4301
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 315s 359ms/step - loss: 0.3576 - accuracy: 0.4301 - val_loss: 0.6790 - val_accuracy: 0.2061
# Epoch 21/30
# 879/879 [==============================] - ETA: 0s - loss: 0.3444 - accuracy: 0.4483
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 316s 360ms/step - loss: 0.3444 - accuracy: 0.4483 - val_loss: 0.6824 - val_accuracy: 0.2094
# Epoch 22/30
# 879/879 [==============================] - ETA: 0s - loss: 0.3314 - accuracy: 0.4657
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 315s 359ms/step - loss: 0.3314 - accuracy: 0.4657 - val_loss: 0.6889 - val_accuracy: 0.2071
# Epoch 23/30
# 879/879 [==============================] - ETA: 0s - loss: 0.3187 - accuracy: 0.4846
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 317s 361ms/step - loss: 0.3187 - accuracy: 0.4846 - val_loss: 0.7013 - val_accuracy: 0.2057
# Epoch 24/30
# 879/879 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.5011
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 315s 359ms/step - loss: 0.3069 - accuracy: 0.5011 - val_loss: 0.7046 - val_accuracy: 0.2094
# Epoch 25/30
# 879/879 [==============================] - ETA: 0s - loss: 0.2962 - accuracy: 0.5174
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 318s 362ms/step - loss: 0.2962 - accuracy: 0.5174 - val_loss: 0.7071 - val_accuracy: 0.2106
# Epoch 26/30
# 879/879 [==============================] - ETA: 0s - loss: 0.2857 - accuracy: 0.5312
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 316s 359ms/step - loss: 0.2857 - accuracy: 0.5312 - val_loss: 0.7153 - val_accuracy: 0.2077
# Epoch 27/30
# 879/879 [==============================] - ETA: 0s - loss: 0.2757 - accuracy: 0.5468
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 317s 361ms/step - loss: 0.2757 - accuracy: 0.5468 - val_loss: 0.7269 - val_accuracy: 0.2075
# Epoch 28/30
# 879/879 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.5604
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 315s 359ms/step - loss: 0.2665 - accuracy: 0.5604 - val_loss: 0.7295 - val_accuracy: 0.2120
# Epoch 29/30
# 879/879 [==============================] - ETA: 0s - loss: 0.2574 - accuracy: 0.5751
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 317s 361ms/step - loss: 0.2574 - accuracy: 0.5751 - val_loss: 0.7372 - val_accuracy: 0.2119
# Epoch 30/30
# 879/879 [==============================] - ETA: 0s - loss: 0.2483 - accuracy: 0.5889
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb17014a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb106664b50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 315s 359ms/step - loss: 0.2483 - accuracy: 0.5889 - val_loss: 0.7476 - val_accuracy: 0.2089

# %%
model1.save_weights('/content/drive/MyDrive/6156 Project/model1_weights.h5')

# %%
model1.load_weights('/content/drive/MyDrive/6156 Project/model1_weights.h5')

# %%
# Eoncoder
encoder_input = Input(shape=(None, ))
encoder_embd = Embedding(JAP_VOCAB_SIZE,1000, mask_zero=True)(encoder_input)
encoder_lstm = LSTM(250, return_state=True)
encoder_output,state_h, state_c = encoder_lstm(encoder_embd)

encoder_states= [state_h, state_c]

# Decoder
decoder_input = Input(shape=(None,))
decoder_embd = Embedding(ENG_VOCAB_SIZE, 1000, mask_zero=True)
decoder_embedding= decoder_embd(decoder_input)
decoder_lstm = LSTM(250, return_state=True,return_sequences=True )
decoder_outputs, _, _= decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense= Dense(ENG_VOCAB_SIZE, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

model2 = Model([encoder_input, decoder_input], decoder_outputs)

# %%
model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics='accuracy')

# %%
checkpoint = ModelCheckpoint("/content/drive/MyDrive/6156 Project/model_checkpoints/model2/", monitor='val_accuracy')

early_stopping = EarlyStopping(monitor='val_accuracy', patience=5)

callbacks_list = [checkpoint, early_stopping]

# %%
steps_per_epoch= np.ceil(len(X_train)/BATCH_SIZE)
steps_per_epoch_val = np.ceil(len(X_train)/BATCH_SIZE)

# %%
EPOCHS= 30 #@param {type:'slider',min:10,max:100, step:10 }
EPOCHS
# Out:
# 30

# %%
history2= model2.fit(data_batch_generator(X_train,y_train), 
                       epochs=EPOCHS,
                       steps_per_epoch= steps_per_epoch,
                     validation_data=data_batch_generator(X_test, y_test, BATCH_SIZE),
                       validation_steps=steps_per_epoch_val,
                     callbacks=callbacks_list)
# Out:
# Epoch 1/30
# 879/879 [==============================] - ETA: 0s - loss: 0.7905 - accuracy: 0.1106
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 356s 397ms/step - loss: 0.7905 - accuracy: 0.1106 - val_loss: 0.7095 - val_accuracy: 0.1548
# Epoch 2/30
# 879/879 [==============================] - ETA: 0s - loss: 0.6523 - accuracy: 0.1775
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 343s 390ms/step - loss: 0.6523 - accuracy: 0.1775 - val_loss: 0.6534 - val_accuracy: 0.1873
# Epoch 3/30
# 879/879 [==============================] - ETA: 0s - loss: 0.5887 - accuracy: 0.2088
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 341s 388ms/step - loss: 0.5887 - accuracy: 0.2088 - val_loss: 0.6237 - val_accuracy: 0.2054
# Epoch 4/30
# 879/879 [==============================] - ETA: 0s - loss: 0.5395 - accuracy: 0.2371
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 342s 389ms/step - loss: 0.5395 - accuracy: 0.2371 - val_loss: 0.6053 - val_accuracy: 0.2175
# Epoch 5/30
# 879/879 [==============================] - ETA: 0s - loss: 0.4989 - accuracy: 0.2635
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 345s 393ms/step - loss: 0.4989 - accuracy: 0.2635 - val_loss: 0.5937 - val_accuracy: 0.2283
# Epoch 6/30
# 879/879 [==============================] - ETA: 0s - loss: 0.4605 - accuracy: 0.2945
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 356s 405ms/step - loss: 0.4605 - accuracy: 0.2945 - val_loss: 0.5878 - val_accuracy: 0.2355
# Epoch 7/30
# 879/879 [==============================] - ETA: 0s - loss: 0.4208 - accuracy: 0.3341
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 352s 401ms/step - loss: 0.4208 - accuracy: 0.3341 - val_loss: 0.5884 - val_accuracy: 0.2412
# Epoch 8/30
# 879/879 [==============================] - ETA: 0s - loss: 0.3786 - accuracy: 0.3864
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 353s 401ms/step - loss: 0.3786 - accuracy: 0.3864 - val_loss: 0.5906 - val_accuracy: 0.2466
# Epoch 9/30
# 879/879 [==============================] - ETA: 0s - loss: 0.3333 - accuracy: 0.4475
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 350s 398ms/step - loss: 0.3333 - accuracy: 0.4475 - val_loss: 0.5984 - val_accuracy: 0.2474
# Epoch 10/30
# 879/879 [==============================] - ETA: 0s - loss: 0.2892 - accuracy: 0.5126
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 350s 399ms/step - loss: 0.2892 - accuracy: 0.5126 - val_loss: 0.6110 - val_accuracy: 0.2504
# Epoch 11/30
# 879/879 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.5775
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 352s 401ms/step - loss: 0.2492 - accuracy: 0.5775 - val_loss: 0.6257 - val_accuracy: 0.2557
# Epoch 12/30
# 879/879 [==============================] - ETA: 0s - loss: 0.2132 - accuracy: 0.6381
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 354s 403ms/step - loss: 0.2132 - accuracy: 0.6381 - val_loss: 0.6360 - val_accuracy: 0.2610
# Epoch 13/30
# 879/879 [==============================] - ETA: 0s - loss: 0.1811 - accuracy: 0.6944
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 352s 401ms/step - loss: 0.1811 - accuracy: 0.6944 - val_loss: 0.6499 - val_accuracy: 0.2620
# Epoch 14/30
# 879/879 [==============================] - ETA: 0s - loss: 0.1536 - accuracy: 0.7434
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 353s 402ms/step - loss: 0.1536 - accuracy: 0.7434 - val_loss: 0.6672 - val_accuracy: 0.2647
# Epoch 15/30
# 879/879 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.7850
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 352s 400ms/step - loss: 0.1299 - accuracy: 0.7850 - val_loss: 0.6811 - val_accuracy: 0.2657
# Epoch 16/30
# 879/879 [==============================] - ETA: 0s - loss: 0.1098 - accuracy: 0.8193
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 353s 402ms/step - loss: 0.1098 - accuracy: 0.8193 - val_loss: 0.6903 - val_accuracy: 0.2702
# Epoch 17/30
# 879/879 [==============================] - ETA: 0s - loss: 0.0930 - accuracy: 0.8479
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 353s 402ms/step - loss: 0.0930 - accuracy: 0.8479 - val_loss: 0.7087 - val_accuracy: 0.2703
# Epoch 18/30
# 879/879 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.8724
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 359s 409ms/step - loss: 0.0785 - accuracy: 0.8724 - val_loss: 0.7208 - val_accuracy: 0.2720
# Epoch 19/30
# 879/879 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 0.8909
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 352s 400ms/step - loss: 0.0667 - accuracy: 0.8909 - val_loss: 0.7305 - val_accuracy: 0.2737
# Epoch 20/30
# 879/879 [==============================] - ETA: 0s - loss: 0.0566 - accuracy: 0.9076
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 353s 402ms/step - loss: 0.0566 - accuracy: 0.9076 - val_loss: 0.7432 - val_accuracy: 0.2724
# Epoch 21/30
# 879/879 [==============================] - ETA: 0s - loss: 0.0482 - accuracy: 0.9214
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 351s 399ms/step - loss: 0.0482 - accuracy: 0.9214 - val_loss: 0.7569 - val_accuracy: 0.2683
# Epoch 22/30
# 879/879 [==============================] - ETA: 0s - loss: 0.0413 - accuracy: 0.9320
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 354s 403ms/step - loss: 0.0413 - accuracy: 0.9320 - val_loss: 0.7693 - val_accuracy: 0.2704
# Epoch 23/30
# 879/879 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9402
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 352s 401ms/step - loss: 0.0358 - accuracy: 0.9402 - val_loss: 0.7842 - val_accuracy: 0.2710
# Epoch 24/30
# 879/879 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9485
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Bhomik - Copy/model_checkpoints/model2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb01f83e290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb09431e950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 879/879 [==============================] - 359s 408ms/step - loss: 0.0309 - accuracy: 0.9485 - val_loss: 0.7975 - val_accuracy: 0.2727

# %%
model2.save_weights('/content/drive/MyDrive/6156 Project/2_model_weights.h5')

# %%
model2.load_weights('/content/drive/MyDrive/6156 Project/2_model_weights.h5')

# %%
encoder_model = Model(encoder_input, encoder_states)

# %%
decoder_state_input_h = Input(shape=(250,))
decoder_state_input_c= Input(shape=(250,))
decoder_states_input= [decoder_state_input_h, decoder_state_input_c]

dec_embd2 = decoder_embd(decoder_input)

decoder_output2,state_h2, state_c2 = decoder_lstm(dec_embd2, initial_state=decoder_states_input)
deccoder_states2= [state_h2, state_c2]

decoder_output2 = decoder_dense(decoder_output2)

decoder_model = Model(
                      [decoder_input]+decoder_states_input,
                      [decoder_output2]+ deccoder_states2)

# %%
def get_predicted_sentence(input_seq):
    states_value = encoder_model.predict(input_seq)
    
    target_seq = np.zeros((1,1))
    
    target_seq[0, 0] = jap_word_index['sos']
    
   
    stop_condition = False
    decoded_sentence = ''
    
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = eng_index_word[sampled_token_index]
        decoded_sentence += ' '+sampled_char
        
        if (sampled_char == 'eos' or len(decoded_sentence) > 50):
            stop_condition = True
        
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index
        
        states_value = [h, c]
    
    return decoded_sentence

# %%
test_gen= data_batch_generator(X_test,y_test,batch_size=1)

# %%
Actual_test_sent = X_test.to_list()
Actual_test_trans= y_test.to_list()

# %%
test_inputs=[]
test_outputs=[]

# %%
from tqdm.notebook import tqdm_notebook
import time
for (input, output),_ in tqdm_notebook(iter(test_gen)):
    test_inputs.append(input)
    test_outputs.append(output)
    time.sleep(0.5)
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-87cf7f0f3a6e> in <module>()
#       4     test_inputs.append(input)
#       5     test_outputs.append(output)
# ----> 6     time.sleep(0.5)
#
# KeyboardInterrupt:

# %%
test_inputs[0]
# Out:
# array([[  117., 38951.,   109.,     0.,     0.,     0.,     0.,     0.,
#             0.,     0.]], dtype=float32)

# %%
test_inputs[1]
# Out:
# array([[ 117., 2032.,  109.,    0.,    0.,    0.,    0.,    0.,    0.,
#            0.]], dtype=float32)

# %%
print("Japanese Sentece:", Actual_test_sent[10])
# Out:
# Japanese Sentece: sos トムが家まで後をつけてメアリーを殺したと彼らは思っている。 eos

# %%
print("Actual English Sentence:", Actual_test_trans[10])
# Out:
# Actual English Sentence: They think Tom followed Mary home and killed her.

# %%
print("Predicted English Translation:", get_predicted_sentence(test_inputs[10]))
# Out:
# Predicted English Translation:  think that Tom followed Mary home and killed her. I
